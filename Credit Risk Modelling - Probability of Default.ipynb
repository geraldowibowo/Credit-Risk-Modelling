# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load Data and Feature Engineering

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col = 0)

# %%
print(loan_data_inputs_train.shape)
print(loan_data_targets_train.shape)
print(loan_data_inputs_test.shape)
print(loan_data_targets_test.shape)
# Out:
# (373028, 324)
# (373028, 1)
# (93257, 324)
# (93257, 1)

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
    'grade:B',
    'grade:C',
    'grade:D',
    'grade:E',
    'grade:F',
    'grade:G',
    'home_ownership:RENT_OTHER_NONE_ANY',
    'home_ownership:OWN',
    'home_ownership:MORTGAGE',
    'addr_state:ND_NE_IA_NV_FL_HI_AL',
    'addr_state:NM_VA',
    'addr_state:NY',
    'addr_state:OK_TN_MO_LA_MD_NC',
    'addr_state:CA',
    'addr_state:UT_KY_AZ_NJ',
    'addr_state:AR_MI_PA_OH_MN',
    'addr_state:RI_MA_DE_SD_IN',
    'addr_state:GA_WA_OR',
    'addr_state:WI_MT',
    'addr_state:TX',
    'addr_state:IL_CT',
    'addr_state:KS_SC_CO_VT_AK_MS',
    'addr_state:WV_NH_WY_DC_ME_ID',
    'verification_status:Not Verified',
    'verification_status:Source Verified',
    'verification_status:Verified',
    'purpose:educ__sm_b__wedd__ren_en__mov__house',
    'purpose:credit_card',
    'purpose:debt_consolidation',
    'purpose:oth__med__vacation',
    'purpose:major_purch__car__home_impr',
    'initial_list_status:f',
    'initial_list_status:w',
    'term:36',
    'term:60',
    'emp_length:0',
    'emp_length:1',
    'emp_length:2-4',
    'emp_length:5-6',
    'emp_length:7-9',
    'emp_length:10',
    'mths_since_issue_d:<38',
    'mths_since_issue_d:38-39',
    'mths_since_issue_d:40-41',
    'mths_since_issue_d:42-48',
    'mths_since_issue_d:49-52',
    'mths_since_issue_d:53-64',
    'mths_since_issue_d:65-84',
    'mths_since_issue_d:>84',
    'int_rate:<9.548',
    'int_rate:9.548-12.025',
    'int_rate:12.025-15.74',
    'int_rate:15.74-20.281',
    'int_rate:>20.281',
    'mths_since_earliest_cr_line:<140',
    'mths_since_earliest_cr_line:141-164',
    'mths_since_earliest_cr_line:165-247',
    'mths_since_earliest_cr_line:248-270',
    'mths_since_earliest_cr_line:271-352',
    'mths_since_earliest_cr_line:>352',
    'delinq_2yrs:0',
    'delinq_2yrs:1-3',
    'delinq_2yrs:>=4',
    'inq_last_6mths:0',
    'inq_last_6mths:1-2',
    'inq_last_6mths:3-6',
    'inq_last_6mths:>6',
    'open_acc:0',
    'open_acc:1-3',
    'open_acc:4-12',
    'open_acc:13-17',
    'open_acc:18-22',
    'open_acc:23-25',
    'open_acc:26-30',
    'open_acc:>=31',
    'pub_rec:0-2',
    'pub_rec:3-4',
    'pub_rec:>=5',
    'total_acc:<=27',
    'total_acc:28-51',
    'total_acc:>=52',
    'acc_now_delinq:0',
    'acc_now_delinq:>=1',
    'total_rev_hi_lim:<=5K',
    'total_rev_hi_lim:5K-10K',
    'total_rev_hi_lim:10K-20K',
    'total_rev_hi_lim:20K-30K',
    'total_rev_hi_lim:30K-40K',
    'total_rev_hi_lim:40K-55K',
    'total_rev_hi_lim:55K-95K',
    'total_rev_hi_lim:>95K',
    'annual_inc:<20K',
    'annual_inc:20K-30K',
    'annual_inc:30K-40K',
    'annual_inc:40K-50K',
    'annual_inc:50K-60K',
    'annual_inc:60K-70K',
    'annual_inc:70K-80K',
    'annual_inc:80K-90K',
    'annual_inc:90K-100K',
    'annual_inc:100K-120K',
    'annual_inc:120K-140K',
    'annual_inc:>140K',
    'dti:<=1.4',
    'dti:1.4-3.5',
    'dti:3.5-7.7',
    'dti:7.7-10.5',
    'dti:10.5-16.1',
    'dti:16.1-20.3',
    'dti:20.3-21.7',
    'dti:21.7-22.4',
    'dti:22.4-35',
    'dti:>35',
    'mths_since_last_delinq:Missing',
    'mths_since_last_delinq:0-3',
    'mths_since_last_delinq:4-30',
    'mths_since_last_delinq:31-56',
    'mths_since_last_delinq:>=57',
    'mths_since_last_record:Missing',
    'mths_since_last_record:0-2',
    'mths_since_last_record:3-20',
    'mths_since_last_record:21-31',
    'mths_since_last_record:32-80',
    'mths_since_last_record:81-86',
    'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
    'home_ownership:RENT_OTHER_NONE_ANY',
    'addr_state:ND_NE_IA_NV_FL_HI_AL',
    'verification_status:Verified',
    'purpose:educ__sm_b__wedd__ren_en__mov__house',
    'initial_list_status:f',
    'term:60',
    'emp_length:0',
    'mths_since_issue_d:>84',
    'int_rate:>20.281',
    'mths_since_earliest_cr_line:<140',
    'delinq_2yrs:>=4',
    'inq_last_6mths:>6',
    'open_acc:0',
    'pub_rec:0-2',
    'total_acc:<=27',
    'acc_now_delinq:0',
    'total_rev_hi_lim:<=5K',
    'annual_inc:<20K',
    'dti:>35',
    'mths_since_last_delinq:0-3',
    'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 427211              0                             0              0
# 206088              0                             0              0
# 136020              0                             0              0
# 412305              0                             0              0
# 36159               0                             0              1
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211                       0                          0
# 206088                       1                          0
# 136020                       0                          0
# 412305                       0                          0
# 36159                        0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 427211                                    1                    0
# 206088                                    0                    0
# 136020                                    0                    0
# 412305                                    1                    0
# 36159                                     0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 427211                                    0                      0        1
# 206088                                    0                      0        1
# 136020                                    0                      0        1
# 412305                                    0                      0        1
# 36159                                     0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 427211             0               1               0               0
# 206088             0               0               1               0
# 136020             0               0               0               0
# 412305             0               0               0               1
# 36159              0               0               1               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211              0                       0                         0
# 206088              0                       0                         0
# 136020              1                       0                         0
# 412305              0                       0                         0
# 36159               0                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 427211                         0                1                      0
# 206088                         0                0                      0
# 136020                         0                1                      0
# 412305                         0                0                      0
# 36159                          0                0                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0
# 206088                      1                      0
# 136020                      0                      0
# 412305                      0                      1
# 36159                       1                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         delinq_2yrs:0  delinq_2yrs:1-3  inq_last_6mths:0  inq_last_6mths:1-2  \
# 427211              1                0                 0                   1
# 206088              0                1                 0                   1
# 136020              1                0                 0                   1
# 412305              0                1                 0                   0
# 36159               1                0                 0                   1
#
#         inq_last_6mths:3-6  open_acc:1-3  open_acc:4-12  open_acc:13-17  \
# 427211                   0             0              0               0
# 206088                   0             0              0               1
# 136020                   0             0              1               0
# 412305                   1             0              1               0
# 36159                    0             0              0               1
#
#         open_acc:18-22  open_acc:23-25  open_acc:26-30  open_acc:>=31  \
# 427211               1               0               0              0
# 206088               0               0               0              0
# 136020               0               0               0              0
# 412305               0               0               0              0
# 36159                0               0               0              0
#
#         pub_rec:3-4  pub_rec:>=5  total_acc:28-51  total_acc:>=52  \
# 427211            0            0                1               0
# 206088            0            0                1               0
# 136020            0            0                0               0
# 412305            0            0                0               0
# 36159             0            0                1               0
#
#         acc_now_delinq:>=1  total_rev_hi_lim:5K-10K  total_rev_hi_lim:10K-20K  \
# 427211                   0                        0                         0
# 206088                   0                        1                         0
# 136020                   0                        0                         0
# 412305                   0                        0                         1
# 36159                    0                        1                         0
#
#         total_rev_hi_lim:20K-30K  total_rev_hi_lim:30K-40K  \
# 427211                         0                         0
# 206088                         0                         0
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         total_rev_hi_lim:40K-55K  total_rev_hi_lim:55K-95K  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         0
# 36159                          0                         0
#
#         total_rev_hi_lim:>95K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                      0                   0                   0
# 206088                      0                   0                   0
# 136020                      0                   0                   0
# 412305                      0                   0                   0
# 36159                       0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 427211              0              0              1            0
# 206088              0              0              0            0
# 136020              0              0              0            0
# 412305              0              0              0            0
# 36159               0              0              0            1
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 427211                               1                            0
# 206088                               0                            1
# 136020                               0                            0
# 412305                               0                            1
# 36159                                1                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 427211                             0                            0
# 206088                             0                            0
# 136020                             1                            0
# 412305                             0                            0
# 36159                              0                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 427211                               1                            0
# 206088                               1                            0
# 136020                               1                            0
# 412305                               1                            0
# 36159                                1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 427211                             0                            0
# 206088                             0                            0
# 136020                             0                            0
# 412305                             0                            0
# 36159                              0                            0

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-1.30510393])

# %%
reg.coef_
# Out:
# array([[ 1.15384687,  0.90206148,  0.70474224,  0.51378647,  0.33148379,
#          0.14038402,  0.09213675,  0.10653056,  0.03270092,  0.05586374,
#          0.05688663,  0.05981672,  0.07566447,  0.13309015,  0.09666713,
#          0.18203255,  0.23378525,  0.22106307,  0.26017087,  0.31753687,
#          0.51689009,  0.0875828 , -0.0100615 ,  0.30551181,  0.20258716,
#          0.21531168,  0.26863513,  0.05361536,  0.07697852,  0.10068005,
#          0.12647724,  0.09168556,  0.06132414,  0.12403475,  1.08494814,
#          0.88301204,  0.78301267,  0.57972772,  0.41741068,  0.1713985 ,
#         -0.06564659,  0.85475074,  0.53917887,  0.29158502,  0.10366258,
#          0.05837015,  0.04074567,  0.08236567,  0.12324354,  0.13010599,
#          0.0692624 ,  0.03237472,  0.67598825,  0.53200164,  0.32342279,
#         -0.00369941, -0.10135194, -0.12657043, -0.14186781, -0.14567462,
#         -0.1087192 , -0.19918292,  0.11982093,  0.17428078, -0.02080309,
#          0.02280527,  0.22807499,  0.03647202,  0.00480847,  0.00299658,
#          0.01667558,  0.03715319,  0.05990996,  0.20396349, -0.06528791,
#          0.00332283,  0.10101751,  0.17000641,  0.24527121,  0.32067025,
#          0.39682607,  0.41580139,  0.49306087,  0.58006888,  0.50729857,
#          0.21235904,  0.34232648,  0.36981342,  0.3103738 ,  0.23454794,
#          0.13690673,  0.12518482,  0.09253296,  0.05228703,  0.10402601,
#          0.16515744,  0.18170875,  0.13428531,  0.23709083,  0.33876717,
#          0.26356699,  0.42083298,  0.06990692,  0.14460442]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             feature name  Coefficients
# 0                              intercept     -1.305104
# 1                                grade:A      1.153847
# 2                                grade:B      0.902061
# 3                                grade:C      0.704742
# 4                                grade:D      0.513786
# 5                                grade:E      0.331484
# 6                                grade:F      0.140384
# 7                     home_ownership:OWN      0.092137
# 8                home_ownership:MORTGAGE      0.106531
# 9                       addr_state:NM_VA      0.032701
# 10                         addr_state:NY      0.055864
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056887
# 12                         addr_state:CA      0.059817
# 13                addr_state:UT_KY_AZ_NJ      0.075664
# 14             addr_state:AR_MI_PA_OH_MN      0.133090
# 15             addr_state:RI_MA_DE_SD_IN      0.096667
# 16                   addr_state:GA_WA_OR      0.182033
# 17                      addr_state:WI_MT      0.233785
# 18                         addr_state:TX      0.221063
# 19                      addr_state:IL_CT      0.260171
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.317537
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.516890
# 22      verification_status:Not Verified      0.087583
# 23   verification_status:Source Verified     -0.010062
# 24                   purpose:credit_card      0.305512
# 25            purpose:debt_consolidation      0.202587
# 26            purpose:oth__med__vacation      0.215312
# 27   purpose:major_purch__car__home_impr      0.268635
# 28                 initial_list_status:w      0.053615
# 29                               term:36      0.076979
# 30                          emp_length:1      0.100680
# 31                        emp_length:2-4      0.126477
# 32                        emp_length:5-6      0.091686
# 33                        emp_length:7-9      0.061324
# 34                         emp_length:10      0.124035
# 35                mths_since_issue_d:<38      1.084948
# 36              mths_since_issue_d:38-39      0.883012
# 37              mths_since_issue_d:40-41      0.783013
# 38              mths_since_issue_d:42-48      0.579728
# 39              mths_since_issue_d:49-52      0.417411
# 40              mths_since_issue_d:53-64      0.171398
# 41              mths_since_issue_d:65-84     -0.065647
# 42                       int_rate:<9.548      0.854751
# 43                 int_rate:9.548-12.025      0.539179
# 44                 int_rate:12.025-15.74      0.291585
# 45                 int_rate:15.74-20.281      0.103663
# 46   mths_since_earliest_cr_line:141-164      0.058370
# 47   mths_since_earliest_cr_line:165-247      0.040746
# 48   mths_since_earliest_cr_line:248-270      0.082366
# 49   mths_since_earliest_cr_line:271-352      0.123244
# 50      mths_since_earliest_cr_line:>352      0.130106
# 51                         delinq_2yrs:0      0.069262
# 52                       delinq_2yrs:1-3      0.032375
# 53                      inq_last_6mths:0      0.675988
# 54                    inq_last_6mths:1-2      0.532002
# 55                    inq_last_6mths:3-6      0.323423
# 56                          open_acc:1-3     -0.003699
# 57                         open_acc:4-12     -0.101352
# 58                        open_acc:13-17     -0.126570
# 59                        open_acc:18-22     -0.141868
# 60                        open_acc:23-25     -0.145675
# 61                        open_acc:26-30     -0.108719
# 62                         open_acc:>=31     -0.199183
# 63                           pub_rec:3-4      0.119821
# 64                           pub_rec:>=5      0.174281
# 65                       total_acc:28-51     -0.020803
# 66                        total_acc:>=52      0.022805
# 67                    acc_now_delinq:>=1      0.228075
# 68               total_rev_hi_lim:5K-10K      0.036472
# 69              total_rev_hi_lim:10K-20K      0.004808
# 70              total_rev_hi_lim:20K-30K      0.002997
# 71              total_rev_hi_lim:30K-40K      0.016676
# 72              total_rev_hi_lim:40K-55K      0.037153
# 73              total_rev_hi_lim:55K-95K      0.059910
# 74                 total_rev_hi_lim:>95K      0.203963
# 75                    annual_inc:20K-30K     -0.065288
# 76                    annual_inc:30K-40K      0.003323
# 77                    annual_inc:40K-50K      0.101018
# 78                    annual_inc:50K-60K      0.170006
# 79                    annual_inc:60K-70K      0.245271
# 80                    annual_inc:70K-80K      0.320670
# 81                    annual_inc:80K-90K      0.396826
# 82                   annual_inc:90K-100K      0.415801
# 83                  annual_inc:100K-120K      0.493061
# 84                  annual_inc:120K-140K      0.580069
# 85                      annual_inc:>140K      0.507299
# 86                             dti:<=1.4      0.212359
# 87                           dti:1.4-3.5      0.342326
# 88                           dti:3.5-7.7      0.369813
# 89                          dti:7.7-10.5      0.310374
# 90                         dti:10.5-16.1      0.234548
# 91                         dti:16.1-20.3      0.136907
# 92                         dti:20.3-21.7      0.125185
# 93                         dti:21.7-22.4      0.092533
# 94                           dti:22.4-35      0.052287
# 95        mths_since_last_delinq:Missing      0.104026
# 96           mths_since_last_delinq:4-30      0.165157
# 97          mths_since_last_delinq:31-56      0.181709
# 98           mths_since_last_delinq:>=57      0.134285
# 99        mths_since_last_record:Missing      0.237091
# 100          mths_since_last_record:3-20      0.338767
# 101         mths_since_last_record:21-31      0.263567
# 102         mths_since_last_record:32-80      0.420833
# 103         mths_since_last_record:81-86      0.069907
# 104          mths_since_last_record:>=86      0.144604

# %% [markdown]
# # Build a Logistic Regression Model with P-Values

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.305104
# 1                                grade:A      1.153847
# 2                                grade:B      0.902061
# 3                                grade:C      0.704742
# 4                                grade:D      0.513786
# 5                                grade:E      0.331484
# 6                                grade:F      0.140384
# 7                     home_ownership:OWN      0.092137
# 8                home_ownership:MORTGAGE      0.106531
# 9                       addr_state:NM_VA      0.032701
# 10                         addr_state:NY      0.055864
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056887
# 12                         addr_state:CA      0.059817
# 13                addr_state:UT_KY_AZ_NJ      0.075664
# 14             addr_state:AR_MI_PA_OH_MN      0.133090
# 15             addr_state:RI_MA_DE_SD_IN      0.096667
# 16                   addr_state:GA_WA_OR      0.182033
# 17                      addr_state:WI_MT      0.233785
# 18                         addr_state:TX      0.221063
# 19                      addr_state:IL_CT      0.260171
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.317537
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.516890
# 22      verification_status:Not Verified      0.087583
# 23   verification_status:Source Verified     -0.010062
# 24                   purpose:credit_card      0.305512
# 25            purpose:debt_consolidation      0.202587
# 26            purpose:oth__med__vacation      0.215312
# 27   purpose:major_purch__car__home_impr      0.268635
# 28                 initial_list_status:w      0.053615
# 29                               term:36      0.076979
# 30                          emp_length:1      0.100680
# 31                        emp_length:2-4      0.126477
# 32                        emp_length:5-6      0.091686
# 33                        emp_length:7-9      0.061324
# 34                         emp_length:10      0.124035
# 35                mths_since_issue_d:<38      1.084948
# 36              mths_since_issue_d:38-39      0.883012
# 37              mths_since_issue_d:40-41      0.783013
# 38              mths_since_issue_d:42-48      0.579728
# 39              mths_since_issue_d:49-52      0.417411
# 40              mths_since_issue_d:53-64      0.171398
# 41              mths_since_issue_d:65-84     -0.065647
# 42                       int_rate:<9.548      0.854751
# 43                 int_rate:9.548-12.025      0.539179
# 44                 int_rate:12.025-15.74      0.291585
# 45                 int_rate:15.74-20.281      0.103663
# 46   mths_since_earliest_cr_line:141-164      0.058370
# 47   mths_since_earliest_cr_line:165-247      0.040746
# 48   mths_since_earliest_cr_line:248-270      0.082366
# 49   mths_since_earliest_cr_line:271-352      0.123244
# 50      mths_since_earliest_cr_line:>352      0.130106
# 51                         delinq_2yrs:0      0.069262
# 52                       delinq_2yrs:1-3      0.032375
# 53                      inq_last_6mths:0      0.675988
# 54                    inq_last_6mths:1-2      0.532002
# 55                    inq_last_6mths:3-6      0.323423
# 56                          open_acc:1-3     -0.003699
# 57                         open_acc:4-12     -0.101352
# 58                        open_acc:13-17     -0.126570
# 59                        open_acc:18-22     -0.141868
# 60                        open_acc:23-25     -0.145675
# 61                        open_acc:26-30     -0.108719
# 62                         open_acc:>=31     -0.199183
# 63                           pub_rec:3-4      0.119821
# 64                           pub_rec:>=5      0.174281
# 65                       total_acc:28-51     -0.020803
# 66                        total_acc:>=52      0.022805
# 67                    acc_now_delinq:>=1      0.228075
# 68               total_rev_hi_lim:5K-10K      0.036472
# 69              total_rev_hi_lim:10K-20K      0.004808
# 70              total_rev_hi_lim:20K-30K      0.002997
# 71              total_rev_hi_lim:30K-40K      0.016676
# 72              total_rev_hi_lim:40K-55K      0.037153
# 73              total_rev_hi_lim:55K-95K      0.059910
# 74                 total_rev_hi_lim:>95K      0.203963
# 75                    annual_inc:20K-30K     -0.065288
# 76                    annual_inc:30K-40K      0.003323
# 77                    annual_inc:40K-50K      0.101018
# 78                    annual_inc:50K-60K      0.170006
# 79                    annual_inc:60K-70K      0.245271
# 80                    annual_inc:70K-80K      0.320670
# 81                    annual_inc:80K-90K      0.396826
# 82                   annual_inc:90K-100K      0.415801
# 83                  annual_inc:100K-120K      0.493061
# 84                  annual_inc:120K-140K      0.580069
# 85                      annual_inc:>140K      0.507299
# 86                             dti:<=1.4      0.212359
# 87                           dti:1.4-3.5      0.342326
# 88                           dti:3.5-7.7      0.369813
# 89                          dti:7.7-10.5      0.310374
# 90                         dti:10.5-16.1      0.234548
# 91                         dti:16.1-20.3      0.136907
# 92                         dti:20.3-21.7      0.125185
# 93                         dti:21.7-22.4      0.092533
# 94                           dti:22.4-35      0.052287
# 95        mths_since_last_delinq:Missing      0.104026
# 96           mths_since_last_delinq:4-30      0.165157
# 97          mths_since_last_delinq:31-56      0.181709
# 98           mths_since_last_delinq:>=57      0.134285
# 99        mths_since_last_record:Missing      0.237091
# 100          mths_since_last_record:3-20      0.338767
# 101         mths_since_last_record:21-31      0.263567
# 102         mths_since_last_record:32-80      0.420833
# 103         mths_since_last_record:81-86      0.069907
# 104          mths_since_last_record:>=86      0.144604

# %%
p_values = reg.p_values
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = np.around(p_values, decimals = 4)
summary_table
# Out:
#                             Feature name  Coefficients  p_values
# 0                              Intercept     -1.305104       NaN
# 1                                grade:A      1.153847    0.0000
# 2                                grade:B      0.902061    0.0000
# 3                                grade:C      0.704742    0.0000
# 4                                grade:D      0.513786    0.0000
# 5                                grade:E      0.331484    0.0000
# 6                                grade:F      0.140384    0.0051
# 7                     home_ownership:OWN      0.092137    0.0000
# 8                home_ownership:MORTGAGE      0.106531    0.0000
# 9                       addr_state:NM_VA      0.032701    0.3077
# 10                         addr_state:NY      0.055864    0.0215
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056887    0.0143
# 12                         addr_state:CA      0.059817    0.0049
# 13                addr_state:UT_KY_AZ_NJ      0.075664    0.0024
# 14             addr_state:AR_MI_PA_OH_MN      0.133090    0.0000
# 15             addr_state:RI_MA_DE_SD_IN      0.096667    0.0012
# 16                   addr_state:GA_WA_OR      0.182033    0.0000
# 17                      addr_state:WI_MT      0.233785    0.0000
# 18                         addr_state:TX      0.221063    0.0000
# 19                      addr_state:IL_CT      0.260171    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.317537    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.516890    0.0000
# 22      verification_status:Not Verified      0.087583    0.0000
# 23   verification_status:Source Verified     -0.010062    0.4552
# 24                   purpose:credit_card      0.305512    0.0000
# 25            purpose:debt_consolidation      0.202587    0.0000
# 26            purpose:oth__med__vacation      0.215312    0.0000
# 27   purpose:major_purch__car__home_impr      0.268635    0.0000
# 28                 initial_list_status:w      0.053615    0.0000
# 29                               term:36      0.076979    0.0000
# 30                          emp_length:1      0.100680    0.0001
# 31                        emp_length:2-4      0.126477    0.0000
# 32                        emp_length:5-6      0.091686    0.0000
# 33                        emp_length:7-9      0.061324    0.0032
# 34                         emp_length:10      0.124035    0.0000
# 35                mths_since_issue_d:<38      1.084948    0.0000
# 36              mths_since_issue_d:38-39      0.883012    0.0000
# 37              mths_since_issue_d:40-41      0.783013    0.0000
# 38              mths_since_issue_d:42-48      0.579728    0.0000
# 39              mths_since_issue_d:49-52      0.417411    0.0000
# 40              mths_since_issue_d:53-64      0.171398    0.0000
# 41              mths_since_issue_d:65-84     -0.065647    0.0245
# 42                       int_rate:<9.548      0.854751    0.0000
# 43                 int_rate:9.548-12.025      0.539179    0.0000
# 44                 int_rate:12.025-15.74      0.291585    0.0000
# 45                 int_rate:15.74-20.281      0.103663    0.0004
# 46   mths_since_earliest_cr_line:141-164      0.058370    0.0194
# 47   mths_since_earliest_cr_line:165-247      0.040746    0.0454
# 48   mths_since_earliest_cr_line:248-270      0.082366    0.0020
# 49   mths_since_earliest_cr_line:271-352      0.123244    0.0000
# 50      mths_since_earliest_cr_line:>352      0.130106    0.0000
# 51                         delinq_2yrs:0      0.069262    0.2249
# 52                       delinq_2yrs:1-3      0.032375    0.5466
# 53                      inq_last_6mths:0      0.675988    0.0000
# 54                    inq_last_6mths:1-2      0.532002    0.0000
# 55                    inq_last_6mths:3-6      0.323423    0.0049
# 56                          open_acc:1-3     -0.003699    0.9821
# 57                         open_acc:4-12     -0.101352    0.5282
# 58                        open_acc:13-17     -0.126570    0.4318
# 59                        open_acc:18-22     -0.141868    0.3811
# 60                        open_acc:23-25     -0.145675    0.3820
# 61                        open_acc:26-30     -0.108719    0.5272
# 62                         open_acc:>=31     -0.199183    0.2841
# 63                           pub_rec:3-4      0.119821    0.2059
# 64                           pub_rec:>=5      0.174281    0.3657
# 65                       total_acc:28-51     -0.020803    0.1430
# 66                        total_acc:>=52      0.022805    0.5658
# 67                    acc_now_delinq:>=1      0.228075    0.0316
# 68               total_rev_hi_lim:5K-10K      0.036472    0.1390
# 69              total_rev_hi_lim:10K-20K      0.004808    0.8405
# 70              total_rev_hi_lim:20K-30K      0.002997    0.9091
# 71              total_rev_hi_lim:30K-40K      0.016676    0.5715
# 72              total_rev_hi_lim:40K-55K      0.037153    0.2482
# 73              total_rev_hi_lim:55K-95K      0.059910    0.0964
# 74                 total_rev_hi_lim:>95K      0.203963    0.0003
# 75                    annual_inc:20K-30K     -0.065288    0.1285
# 76                    annual_inc:30K-40K      0.003323    0.9361
# 77                    annual_inc:40K-50K      0.101018    0.0149
# 78                    annual_inc:50K-60K      0.170006    0.0001
# 79                    annual_inc:60K-70K      0.245271    0.0000
# 80                    annual_inc:70K-80K      0.320670    0.0000
# 81                    annual_inc:80K-90K      0.396826    0.0000
# 82                   annual_inc:90K-100K      0.415801    0.0000
# 83                  annual_inc:100K-120K      0.493061    0.0000
# 84                  annual_inc:120K-140K      0.580069    0.0000
# 85                      annual_inc:>140K      0.507299    0.0000
# 86                             dti:<=1.4      0.212359    0.0162
# 87                           dti:1.4-3.5      0.342326    0.0000
# 88                           dti:3.5-7.7      0.369813    0.0000
# 89                          dti:7.7-10.5      0.310374    0.0000
# 90                         dti:10.5-16.1      0.234548    0.0002
# 91                         dti:16.1-20.3      0.136907    0.0286
# 92                         dti:20.3-21.7      0.125185    0.0541
# 93                         dti:21.7-22.4      0.092533    0.1788
# 94                           dti:22.4-35      0.052287    0.3975
# 95        mths_since_last_delinq:Missing      0.104026    0.0651
# 96           mths_since_last_delinq:4-30      0.165157    0.0016
# 97          mths_since_last_delinq:31-56      0.181709    0.0016
# 98           mths_since_last_delinq:>=57      0.134285    0.0222
# 99        mths_since_last_record:Missing      0.237091    0.0020
# 100          mths_since_last_record:3-20      0.338767    0.0051
# 101         mths_since_last_record:21-31      0.263567    0.0165
# 102         mths_since_last_record:32-80      0.420833    0.0000
# 103         mths_since_last_record:81-86      0.069907    0.4302
# 104          mths_since_last_record:>=86      0.144604    0.0649

# %% [markdown]
# ### If the coefficients for none of the dummy variables are significant, we should remove. Otherwise, keep all of the dummy variables. If P-Values is below 0.05, it means the variable is significant.

# %% [markdown]
# - e.g. grades and home ownership are signidicant
# - e.g. verification_status  is still significant
# - e.g. delinq_2yrs,pub_rec, total_acc, open_acc not significant (need to remove)
#
# - e.g. total_rev_hi_lim only has 1 out of 5 dummy variable that is significant, therefore, can be removed

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
    'grade:B',
    'grade:C',
    'grade:D',
    'grade:E',
    'grade:F',
    'grade:G',
    'home_ownership:RENT_OTHER_NONE_ANY',
    'home_ownership:OWN',
    'home_ownership:MORTGAGE',
    'addr_state:ND_NE_IA_NV_FL_HI_AL',
    'addr_state:NM_VA',
    'addr_state:NY',
    'addr_state:OK_TN_MO_LA_MD_NC',
    'addr_state:CA',
    'addr_state:UT_KY_AZ_NJ',
    'addr_state:AR_MI_PA_OH_MN',
    'addr_state:RI_MA_DE_SD_IN',
    'addr_state:GA_WA_OR',
    'addr_state:WI_MT',
    'addr_state:TX',
    'addr_state:IL_CT',
    'addr_state:KS_SC_CO_VT_AK_MS',
    'addr_state:WV_NH_WY_DC_ME_ID',
    'verification_status:Not Verified',
    'verification_status:Source Verified',
    'verification_status:Verified',
    'purpose:educ__sm_b__wedd__ren_en__mov__house',
    'purpose:credit_card',
    'purpose:debt_consolidation',
    'purpose:oth__med__vacation',
    'purpose:major_purch__car__home_impr',
    'initial_list_status:f',
    'initial_list_status:w',
    'term:36',
    'term:60',
    'emp_length:0',
    'emp_length:1',
    'emp_length:2-4',
    'emp_length:5-6',
    'emp_length:7-9',
    'emp_length:10',
    'mths_since_issue_d:<38',
    'mths_since_issue_d:38-39',
    'mths_since_issue_d:40-41',
    'mths_since_issue_d:42-48',
    'mths_since_issue_d:49-52',
    'mths_since_issue_d:53-64',
    'mths_since_issue_d:65-84',
    'mths_since_issue_d:>84',
    'int_rate:<9.548',
    'int_rate:9.548-12.025',
    'int_rate:12.025-15.74',
    'int_rate:15.74-20.281',
    'int_rate:>20.281',
    'mths_since_earliest_cr_line:<140',
    'mths_since_earliest_cr_line:141-164',
    'mths_since_earliest_cr_line:165-247',
    'mths_since_earliest_cr_line:248-270',
    'mths_since_earliest_cr_line:271-352',
    'mths_since_earliest_cr_line:>352',
#     'delinq_2yrs:0',
#     'delinq_2yrs:1-3',
#     'delinq_2yrs:>=4',
    'inq_last_6mths:0',
    'inq_last_6mths:1-2',
    'inq_last_6mths:3-6',
    'inq_last_6mths:>6',
#     'open_acc:0',
#     'open_acc:1-3',
#     'open_acc:4-12',
#     'open_acc:13-17',
#     'open_acc:18-22',
#     'open_acc:23-25',
#     'open_acc:26-30',
#     'open_acc:>=31',
#     'pub_rec:0-2',
#     'pub_rec:3-4',
#     'pub_rec:>=5',
#     'total_acc:<=27',
#     'total_acc:28-51',
#     'total_acc:>=52',
    'acc_now_delinq:0',
    'acc_now_delinq:>=1',
#     'total_rev_hi_lim:<=5K',
#     'total_rev_hi_lim:5K-10K',
#     'total_rev_hi_lim:10K-20K',
#     'total_rev_hi_lim:20K-30K',
#     'total_rev_hi_lim:30K-40K',
#     'total_rev_hi_lim:40K-55K',
#     'total_rev_hi_lim:55K-95K',
#     'total_rev_hi_lim:>95K',
    'annual_inc:<20K',
    'annual_inc:20K-30K',
    'annual_inc:30K-40K',
    'annual_inc:40K-50K',
    'annual_inc:50K-60K',
    'annual_inc:60K-70K',
    'annual_inc:70K-80K',
    'annual_inc:80K-90K',
    'annual_inc:90K-100K',
    'annual_inc:100K-120K',
    'annual_inc:120K-140K',
    'annual_inc:>140K',
    'dti:<=1.4',
    'dti:1.4-3.5',
    'dti:3.5-7.7',
    'dti:7.7-10.5',
    'dti:10.5-16.1',
    'dti:16.1-20.3',
    'dti:20.3-21.7',
    'dti:21.7-22.4',
    'dti:22.4-35',
    'dti:>35',
    'mths_since_last_delinq:Missing',
    'mths_since_last_delinq:0-3',
    'mths_since_last_delinq:4-30',
    'mths_since_last_delinq:31-56',
    'mths_since_last_delinq:>=57',
    'mths_since_last_record:Missing',
    'mths_since_last_record:0-2',
    'mths_since_last_record:3-20',
    'mths_since_last_record:21-31',
    'mths_since_last_record:32-80',
    'mths_since_last_record:81-86',
    'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 427211              0                             0              0
# 206088              0                             0              0
# 136020              0                             0              0
# 412305              0                             0              0
# 36159               0                             0              1
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211                       0                          0
# 206088                       1                          0
# 136020                       0                          0
# 412305                       0                          0
# 36159                        0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 427211                                    1                    0
# 206088                                    0                    0
# 136020                                    0                    0
# 412305                                    1                    0
# 36159                                     0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 427211                                    0                      0        1
# 206088                                    0                      0        1
# 136020                                    0                      0        1
# 412305                                    0                      0        1
# 36159                                     0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 427211             0               1               0               0
# 206088             0               0               1               0
# 136020             0               0               0               0
# 412305             0               0               0               1
# 36159              0               0               1               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211              0                       0                         0
# 206088              0                       0                         0
# 136020              1                       0                         0
# 412305              0                       0                         0
# 36159               0                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 427211                         0                1                      0
# 206088                         0                0                      0
# 136020                         0                1                      0
# 412305                         0                0                      0
# 36159                          0                0                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0
# 206088                      1                      0
# 136020                      0                      0
# 412305                      0                      1
# 36159                       1                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 427211                 0                   1                   0
# 206088                 0                   1                   0
# 136020                 0                   1                   0
# 412305                 0                   0                   1
# 36159                  0                   1                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   0                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 427211              0              0              1            0
# 206088              0              0              0            0
# 136020              0              0              0            0
# 412305              0              0              0            0
# 36159               0              0              0            1
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 427211                               1                            0
# 206088                               0                            1
# 136020                               0                            0
# 412305                               0                            1
# 36159                                1                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 427211                             0                            0
# 206088                             0                            0
# 136020                             1                            0
# 412305                             0                            0
# 36159                              0                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 427211                               1                            0
# 206088                               1                            0
# 136020                               1                            0
# 412305                               1                            0
# 36159                                1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 427211                             0                            0
# 206088                             0                            0
# 136020                             0                            0
# 412305                             0                            0
# 36159                              0                            0

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Geraldo Wibowo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.285478
# 1                               grade:A      1.141219
# 2                               grade:B      0.885134
# 3                               grade:C      0.690067
# 4                               grade:D      0.502034
# 5                               grade:E      0.326603
# 6                               grade:F      0.136833
# 7                    home_ownership:OWN      0.091909
# 8               home_ownership:MORTGAGE      0.106068
# 9                      addr_state:NM_VA      0.028894
# 10                        addr_state:NY      0.051285
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12                        addr_state:CA      0.057933
# 13               addr_state:UT_KY_AZ_NJ      0.073062
# 14            addr_state:AR_MI_PA_OH_MN      0.130200
# 15            addr_state:RI_MA_DE_SD_IN      0.094414
# 16                  addr_state:GA_WA_OR      0.180150
# 17                     addr_state:WI_MT      0.223667
# 18                        addr_state:TX      0.216846
# 19                     addr_state:IL_CT      0.256028
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22     verification_status:Not Verified      0.084616
# 23  verification_status:Source Verified     -0.010895
# 24                  purpose:credit_card      0.305107
# 25           purpose:debt_consolidation      0.201227
# 26           purpose:oth__med__vacation      0.217117
# 27  purpose:major_purch__car__home_impr      0.269177
# 28                initial_list_status:w      0.054367
# 29                              term:36      0.078434
# 30                         emp_length:1      0.100007
# 31                       emp_length:2-4      0.126244
# 32                       emp_length:5-6      0.091491
# 33                       emp_length:7-9      0.061723
# 34                        emp_length:10      0.125873
# 35               mths_since_issue_d:<38      1.091351
# 36             mths_since_issue_d:38-39      0.886866
# 37             mths_since_issue_d:40-41      0.786364
# 38             mths_since_issue_d:42-48      0.585583
# 39             mths_since_issue_d:49-52      0.424524
# 40             mths_since_issue_d:53-64      0.178538
# 41             mths_since_issue_d:65-84     -0.062583
# 42                      int_rate:<9.548      0.872003
# 43                int_rate:9.548-12.025      0.557210
# 44                int_rate:12.025-15.74      0.305648
# 45                int_rate:15.74-20.281      0.112880
# 46  mths_since_earliest_cr_line:141-164      0.054014
# 47  mths_since_earliest_cr_line:165-247      0.035973
# 48  mths_since_earliest_cr_line:248-270      0.077428
# 49  mths_since_earliest_cr_line:271-352      0.120513
# 50     mths_since_earliest_cr_line:>352      0.128505
# 51                     inq_last_6mths:0      0.655859
# 52                   inq_last_6mths:1-2      0.509582
# 53                   inq_last_6mths:3-6      0.299320
# 54                   acc_now_delinq:>=1      0.201684
# 55                   annual_inc:20K-30K     -0.079788
# 56                   annual_inc:30K-40K     -0.017641
# 57                   annual_inc:40K-50K      0.077229
# 58                   annual_inc:50K-60K      0.144130
# 59                   annual_inc:60K-70K      0.219688
# 60                   annual_inc:70K-80K      0.293108
# 61                   annual_inc:80K-90K      0.368871
# 62                  annual_inc:90K-100K      0.389257
# 63                 annual_inc:100K-120K      0.466807
# 64                 annual_inc:120K-140K      0.557062
# 65                     annual_inc:>140K      0.494627
# 66                            dti:<=1.4      0.242920
# 67                          dti:1.4-3.5      0.362306
# 68                          dti:3.5-7.7      0.377527
# 69                         dti:7.7-10.5      0.313164
# 70                        dti:10.5-16.1      0.233756
# 71                        dti:16.1-20.3      0.132411
# 72                        dti:20.3-21.7      0.120198
# 73                        dti:21.7-22.4      0.084503
# 74                          dti:22.4-35      0.043014
# 75       mths_since_last_delinq:Missing      0.133271
# 76          mths_since_last_delinq:4-30      0.159556
# 77         mths_since_last_delinq:31-56      0.205905
# 78          mths_since_last_delinq:>=57      0.158590
# 79       mths_since_last_record:Missing      0.214644
# 80          mths_since_last_record:3-20      0.330379
# 81         mths_since_last_record:21-31      0.231732
# 82         mths_since_last_record:32-80      0.397450
# 83         mths_since_last_record:81-86      0.044308
# 84          mths_since_last_record:>=86      0.119907

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = np.around(p_values, decimals = 4)
summary_table
# Out:
#                            Feature name  Coefficients  p_values
# 0                             Intercept     -1.285478       NaN
# 1                               grade:A      1.141219    0.0000
# 2                               grade:B      0.885134    0.0000
# 3                               grade:C      0.690067    0.0000
# 4                               grade:D      0.502034    0.0000
# 5                               grade:E      0.326603    0.0000
# 6                               grade:F      0.136833    0.0053
# 7                    home_ownership:OWN      0.091909    0.0000
# 8               home_ownership:MORTGAGE      0.106068    0.0000
# 9                      addr_state:NM_VA      0.028894    0.3668
# 10                        addr_state:NY      0.051285    0.0343
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.053486    0.0209
# 12                        addr_state:CA      0.057933    0.0063
# 13               addr_state:UT_KY_AZ_NJ      0.073062    0.0034
# 14            addr_state:AR_MI_PA_OH_MN      0.130200    0.0000
# 15            addr_state:RI_MA_DE_SD_IN      0.094414    0.0016
# 16                  addr_state:GA_WA_OR      0.180150    0.0000
# 17                     addr_state:WI_MT      0.223667    0.0000
# 18                        addr_state:TX      0.216846    0.0000
# 19                     addr_state:IL_CT      0.256028    0.0000
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.314907    0.0000
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.516382    0.0000
# 22     verification_status:Not Verified      0.084616    0.0000
# 23  verification_status:Source Verified     -0.010895    0.4172
# 24                  purpose:credit_card      0.305107    0.0000
# 25           purpose:debt_consolidation      0.201227    0.0000
# 26           purpose:oth__med__vacation      0.217117    0.0000
# 27  purpose:major_purch__car__home_impr      0.269177    0.0000
# 28                initial_list_status:w      0.054367    0.0000
# 29                              term:36      0.078434    0.0000
# 30                         emp_length:1      0.100007    0.0001
# 31                       emp_length:2-4      0.126244    0.0000
# 32                       emp_length:5-6      0.091491    0.0000
# 33                       emp_length:7-9      0.061723    0.0030
# 34                        emp_length:10      0.125873    0.0000
# 35               mths_since_issue_d:<38      1.091351    0.0000
# 36             mths_since_issue_d:38-39      0.886866    0.0000
# 37             mths_since_issue_d:40-41      0.786364    0.0000
# 38             mths_since_issue_d:42-48      0.585583    0.0000
# 39             mths_since_issue_d:49-52      0.424524    0.0000
# 40             mths_since_issue_d:53-64      0.178538    0.0000
# 41             mths_since_issue_d:65-84     -0.062583    0.0314
# 42                      int_rate:<9.548      0.872003    0.0000
# 43                int_rate:9.548-12.025      0.557210    0.0000
# 44                int_rate:12.025-15.74      0.305648    0.0000
# 45                int_rate:15.74-20.281      0.112880    0.0001
# 46  mths_since_earliest_cr_line:141-164      0.054014    0.0299
# 47  mths_since_earliest_cr_line:165-247      0.035973    0.0732
# 48  mths_since_earliest_cr_line:248-270      0.077428    0.0032
# 49  mths_since_earliest_cr_line:271-352      0.120513    0.0000
# 50     mths_since_earliest_cr_line:>352      0.128505    0.0000
# 51                     inq_last_6mths:0      0.655859    0.0000
# 52                   inq_last_6mths:1-2      0.509582    0.0000
# 53                   inq_last_6mths:3-6      0.299320    0.0006
# 54                   acc_now_delinq:>=1      0.201684    0.0556
# 55                   annual_inc:20K-30K     -0.079788    0.0580
# 56                   annual_inc:30K-40K     -0.017641    0.6627
# 57                   annual_inc:40K-50K      0.077229    0.0559
# 58                   annual_inc:50K-60K      0.144130    0.0004
# 59                   annual_inc:60K-70K      0.219688    0.0000
# 60                   annual_inc:70K-80K      0.293108    0.0000
# 61                   annual_inc:80K-90K      0.368871    0.0000
# 62                  annual_inc:90K-100K      0.389257    0.0000
# 63                 annual_inc:100K-120K      0.466807    0.0000
# 64                 annual_inc:120K-140K      0.557062    0.0000
# 65                     annual_inc:>140K      0.494627    0.0000
# 66                            dti:<=1.4      0.242920    0.0036
# 67                          dti:1.4-3.5      0.362306    0.0000
# 68                          dti:3.5-7.7      0.377527    0.0000
# 69                         dti:7.7-10.5      0.313164    0.0000
# 70                        dti:10.5-16.1      0.233756    0.0001
# 71                        dti:16.1-20.3      0.132411    0.0224
# 72                        dti:20.3-21.7      0.120198    0.0476
# 73                        dti:21.7-22.4      0.084503    0.1919
# 74                          dti:22.4-35      0.043014    0.4529
# 75       mths_since_last_delinq:Missing      0.133271    0.0091
# 76          mths_since_last_delinq:4-30      0.159556    0.0020
# 77         mths_since_last_delinq:31-56      0.205905    0.0001
# 78          mths_since_last_delinq:>=57      0.158590    0.0031
# 79       mths_since_last_record:Missing      0.214644    0.0033
# 80          mths_since_last_record:3-20      0.330379    0.0049
# 81         mths_since_last_record:21-31      0.231732    0.0294
# 82         mths_since_last_record:32-80      0.397450    0.0000
# 83         mths_since_last_record:81-86      0.044308    0.6077
# 84          mths_since_last_record:>=86      0.119907    0.1095

# %%
import pickle
pickle.dump(reg2, open('pd_model.sav', 'wb'))

# %% [markdown]
# # PD Model Validation

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
    'grade:B',
    'grade:C',
    'grade:D',
    'grade:E',
    'grade:F',
    'grade:G',
    'home_ownership:RENT_OTHER_NONE_ANY',
    'home_ownership:OWN',
    'home_ownership:MORTGAGE',
    'addr_state:ND_NE_IA_NV_FL_HI_AL',
    'addr_state:NM_VA',
    'addr_state:NY',
    'addr_state:OK_TN_MO_LA_MD_NC',
    'addr_state:CA',
    'addr_state:UT_KY_AZ_NJ',
    'addr_state:AR_MI_PA_OH_MN',
    'addr_state:RI_MA_DE_SD_IN',
    'addr_state:GA_WA_OR',
    'addr_state:WI_MT',
    'addr_state:TX',
    'addr_state:IL_CT',
    'addr_state:KS_SC_CO_VT_AK_MS',
    'addr_state:WV_NH_WY_DC_ME_ID',
    'verification_status:Not Verified',
    'verification_status:Source Verified',
    'verification_status:Verified',
    'purpose:educ__sm_b__wedd__ren_en__mov__house',
    'purpose:credit_card',
    'purpose:debt_consolidation',
    'purpose:oth__med__vacation',
    'purpose:major_purch__car__home_impr',
    'initial_list_status:f',
    'initial_list_status:w',
    'term:36',
    'term:60',
    'emp_length:0',
    'emp_length:1',
    'emp_length:2-4',
    'emp_length:5-6',
    'emp_length:7-9',
    'emp_length:10',
    'mths_since_issue_d:<38',
    'mths_since_issue_d:38-39',
    'mths_since_issue_d:40-41',
    'mths_since_issue_d:42-48',
    'mths_since_issue_d:49-52',
    'mths_since_issue_d:53-64',
    'mths_since_issue_d:65-84',
    'mths_since_issue_d:>84',
    'int_rate:<9.548',
    'int_rate:9.548-12.025',
    'int_rate:12.025-15.74',
    'int_rate:15.74-20.281',
    'int_rate:>20.281',
    'mths_since_earliest_cr_line:<140',
    'mths_since_earliest_cr_line:141-164',
    'mths_since_earliest_cr_line:165-247',
    'mths_since_earliest_cr_line:248-270',
    'mths_since_earliest_cr_line:271-352',
    'mths_since_earliest_cr_line:>352',
    'inq_last_6mths:0',
    'inq_last_6mths:1-2',
    'inq_last_6mths:3-6',
    'inq_last_6mths:>6',
    'acc_now_delinq:0',
    'acc_now_delinq:>=1',
    'annual_inc:<20K',
    'annual_inc:20K-30K',
    'annual_inc:30K-40K',
    'annual_inc:40K-50K',
    'annual_inc:50K-60K',
    'annual_inc:60K-70K',
    'annual_inc:70K-80K',
    'annual_inc:80K-90K',
    'annual_inc:90K-100K',
    'annual_inc:100K-120K',
    'annual_inc:120K-140K',
    'annual_inc:>140K',
    'dti:<=1.4',
    'dti:1.4-3.5',
    'dti:3.5-7.7',
    'dti:7.7-10.5',
    'dti:10.5-16.1',
    'dti:16.1-20.3',
    'dti:20.3-21.7',
    'dti:21.7-22.4',
    'dti:22.4-35',
    'dti:>35',
    'mths_since_last_delinq:Missing',
    'mths_since_last_delinq:0-3',
    'mths_since_last_delinq:4-30',
    'mths_since_last_delinq:31-56',
    'mths_since_last_delinq:>=57',
    'mths_since_last_record:Missing',
    'mths_since_last_record:0-2',
    'mths_since_last_record:3-20',
    'mths_since_last_record:21-31',
    'mths_since_last_record:32-80',
    'mths_since_last_record:81-86',
    'mths_since_last_record:>=86']]

ref_categories = ['grade:G',
    'home_ownership:RENT_OTHER_NONE_ANY',
    'addr_state:ND_NE_IA_NV_FL_HI_AL',
    'verification_status:Verified',
    'purpose:educ__sm_b__wedd__ren_en__mov__house',
    'initial_list_status:f',
    'term:60',
    'emp_length:0',
    'mths_since_issue_d:>84',
    'int_rate:>20.281',
    'mths_since_earliest_cr_line:<140',
    'inq_last_6mths:>6',
    'acc_now_delinq:0',
    'annual_inc:<20K',
    'dti:>35',
    'mths_since_last_delinq:0-3',
    'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      1                      0
# 288564                      0                      0
# 213591                      1                      0
# 263083                      1                      0
# 165001                      0                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0              0            0
# 288564              0              0              0            1
# 213591              0              0              0            0
# 263083              1              0              0            0
# 165001              0              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
y_hat_test = reg2.model.predict(inputs_test)
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

#see the proability of not default
y_hat_test_proba = y_hat_test_proba[: ][: , 1]
y_hat_test_proba
# Out:
# array([0.92430821, 0.84650386, 0.88566594, ..., 0.97329466, 0.95988081,
#        0.95238245])

# %%
loan_data_targets_test_temp = loan_data_targets_test
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)
loan_data_targets_test_temp.head()
# Out:
#    good_bad
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, 
                                       pd.DataFrame(y_hat_test_proba)], axis = 1)
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']
df_actual_predicted_probs.index = loan_data_inputs_test.index
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1          0.924308
# 288564                       1          0.846504
# 213591                       1          0.885666
# 263083                       1          0.940737
# 165001                       1          0.968782

# %% [markdown]
# # Accuracy Test and Area Under Curve

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
            df_actual_predicted_probs['y_hat_test'],
            rownames = ['Actual'], 
            colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7379   2811
# 1          35799  47268

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
            df_actual_predicted_probs['y_hat_test'],
            rownames = ['Actual'], 
            colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.079125  0.030143
# 1          0.383875  0.506857

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
             df_actual_predicted_probs['y_hat_test'],
             rownames = ['Actual'], 
             colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
                                                                                                       df_actual_predicted_probs['y_hat_test'],
             
             rownames = ['Actual'], 
             colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5859828216648616

# %% [markdown]
# ### Accuracy is not the universal measure for a PD model

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'],
                                 df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
AUROC
# Out:
# 0.7021157560682686

# %% [markdown]
# # Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba')
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0  39810                       0          0.393244           0
# 1  42341                       1          0.393928           0
# 2  42344                       1          0.417324           0
# 3  40518                       0          0.448182           0
# 4  40173                       0          0.468557           0

# %% [markdown]
# #### Find the cumulative good and bad population

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  39810                       0          0.393244           0
# 1  42341                       1          0.393928           0
# 2  42344                       1          0.417324           0
# 3  40518                       0          0.448182           0
# 4  40173                       0          0.468557           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / df_actual_predicted_probs['loan_data_targets_test'].sum()
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  39810                       0          0.393244           0
# 1  42341                       1          0.393928           0
# 2  42344                       1          0.417324           0
# 3  40518                       0          0.448182           0
# 4  40173                       0          0.468557           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3
#
#    Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 0                    0.000011              0.000000             0.000098
# 1                    0.000021              0.000012             0.000098
# 2                    0.000032              0.000024             0.000098
# 3                    0.000043              0.000024             0.000196
# 4                    0.000054              0.000024             0.000294

# %% [markdown]
# #### Cumulative in terms of percentage

# %%
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], 
         df_actual_predicted_probs['Cumulative Perc Bad'])

plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], 
         df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')

plt.xlabel('Cumulative % Population')
plt.ylabel('Cumulative % Bad')
plt.title('Gini')
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 - 1
Gini
# Out:
# 0.4042315121365372

# %%
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], 
         df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')

plt.plot(df_actual_predicted_probs['y_hat_test_proba'], 
         df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')

plt.xlabel('Estimated Probability for being Good')
plt.ylabel('Cumulative %')
plt.title('Kolmogorov-Smirnov')
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %%
KS = max(df_actual_predicted_probs['Cumulative Perc Bad'] - df_actual_predicted_probs['Cumulative Perc Good'])
KS
# Out:
# 0.29652196762363797

# %% [markdown]
# # Applying the PD Model

# %% [markdown]
# ### Calculating PD of individual accounts

# %%
pd.options.display.max_columns = None

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
summary_table
# Out:
#                            Feature name  Coefficients  p_values
# 0                             Intercept     -1.285478       NaN
# 1                               grade:A      1.141219    0.0000
# 2                               grade:B      0.885134    0.0000
# 3                               grade:C      0.690067    0.0000
# 4                               grade:D      0.502034    0.0000
# 5                               grade:E      0.326603    0.0000
# 6                               grade:F      0.136833    0.0053
# 7                    home_ownership:OWN      0.091909    0.0000
# 8               home_ownership:MORTGAGE      0.106068    0.0000
# 9                      addr_state:NM_VA      0.028894    0.3668
# 10                        addr_state:NY      0.051285    0.0343
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.053486    0.0209
# 12                        addr_state:CA      0.057933    0.0063
# 13               addr_state:UT_KY_AZ_NJ      0.073062    0.0034
# 14            addr_state:AR_MI_PA_OH_MN      0.130200    0.0000
# 15            addr_state:RI_MA_DE_SD_IN      0.094414    0.0016
# 16                  addr_state:GA_WA_OR      0.180150    0.0000
# 17                     addr_state:WI_MT      0.223667    0.0000
# 18                        addr_state:TX      0.216846    0.0000
# 19                     addr_state:IL_CT      0.256028    0.0000
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.314907    0.0000
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.516382    0.0000
# 22     verification_status:Not Verified      0.084616    0.0000
# 23  verification_status:Source Verified     -0.010895    0.4172
# 24                  purpose:credit_card      0.305107    0.0000
# 25           purpose:debt_consolidation      0.201227    0.0000
# 26           purpose:oth__med__vacation      0.217117    0.0000
# 27  purpose:major_purch__car__home_impr      0.269177    0.0000
# 28                initial_list_status:w      0.054367    0.0000
# 29                              term:36      0.078434    0.0000
# 30                         emp_length:1      0.100007    0.0001
# 31                       emp_length:2-4      0.126244    0.0000
# 32                       emp_length:5-6      0.091491    0.0000
# 33                       emp_length:7-9      0.061723    0.0030
# 34                        emp_length:10      0.125873    0.0000
# 35               mths_since_issue_d:<38      1.091351    0.0000
# 36             mths_since_issue_d:38-39      0.886866    0.0000
# 37             mths_since_issue_d:40-41      0.786364    0.0000
# 38             mths_since_issue_d:42-48      0.585583    0.0000
# 39             mths_since_issue_d:49-52      0.424524    0.0000
# 40             mths_since_issue_d:53-64      0.178538    0.0000
# 41             mths_since_issue_d:65-84     -0.062583    0.0314
# 42                      int_rate:<9.548      0.872003    0.0000
# 43                int_rate:9.548-12.025      0.557210    0.0000
# 44                int_rate:12.025-15.74      0.305648    0.0000
# 45                int_rate:15.74-20.281      0.112880    0.0001
# 46  mths_since_earliest_cr_line:141-164      0.054014    0.0299
# 47  mths_since_earliest_cr_line:165-247      0.035973    0.0732
# 48  mths_since_earliest_cr_line:248-270      0.077428    0.0032
# 49  mths_since_earliest_cr_line:271-352      0.120513    0.0000
# 50     mths_since_earliest_cr_line:>352      0.128505    0.0000
# 51                     inq_last_6mths:0      0.655859    0.0000
# 52                   inq_last_6mths:1-2      0.509582    0.0000
# 53                   inq_last_6mths:3-6      0.299320    0.0006
# 54                   acc_now_delinq:>=1      0.201684    0.0556
# 55                   annual_inc:20K-30K     -0.079788    0.0580
# 56                   annual_inc:30K-40K     -0.017641    0.6627
# 57                   annual_inc:40K-50K      0.077229    0.0559
# 58                   annual_inc:50K-60K      0.144130    0.0004
# 59                   annual_inc:60K-70K      0.219688    0.0000
# 60                   annual_inc:70K-80K      0.293108    0.0000
# 61                   annual_inc:80K-90K      0.368871    0.0000
# 62                  annual_inc:90K-100K      0.389257    0.0000
# 63                 annual_inc:100K-120K      0.466807    0.0000
# 64                 annual_inc:120K-140K      0.557062    0.0000
# 65                     annual_inc:>140K      0.494627    0.0000
# 66                            dti:<=1.4      0.242920    0.0036
# 67                          dti:1.4-3.5      0.362306    0.0000
# 68                          dti:3.5-7.7      0.377527    0.0000
# 69                         dti:7.7-10.5      0.313164    0.0000
# 70                        dti:10.5-16.1      0.233756    0.0001
# 71                        dti:16.1-20.3      0.132411    0.0224
# 72                        dti:20.3-21.7      0.120198    0.0476
# 73                        dti:21.7-22.4      0.084503    0.1919
# 74                          dti:22.4-35      0.043014    0.4529
# 75       mths_since_last_delinq:Missing      0.133271    0.0091
# 76          mths_since_last_delinq:4-30      0.159556    0.0020
# 77         mths_since_last_delinq:31-56      0.205905    0.0001
# 78          mths_since_last_delinq:>=57      0.158590    0.0031
# 79       mths_since_last_record:Missing      0.214644    0.0033
# 80          mths_since_last_record:3-20      0.330379    0.0049
# 81         mths_since_last_record:21-31      0.231732    0.0294
# 82         mths_since_last_record:32-80      0.397450    0.0000
# 83         mths_since_last_record:81-86      0.044308    0.6077
# 84          mths_since_last_record:>=86      0.119907    0.1095

# %%
y_hat_test_proba
# Out:
# array([0.92430821, 0.84650386, 0.88566594, ..., 0.97329466, 0.95988081,
#        0.95238245])

# %% [markdown]
# ### Create Scoreboard

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
df_ref_categories['Coefficients'] = 0
df_ref_categories['p_values'] = np.nan
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10              mths_since_earliest_cr_line:<140             0       NaN
# 11                             inq_last_6mths:>6             0       NaN
# 12                              acc_now_delinq:0             0       NaN
# 13                               annual_inc:<20K             0       NaN
# 14                                       dti:>35             0       NaN
# 15                    mths_since_last_delinq:0-3             0       NaN
# 16                    mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
df_scorecard = df_scorecard.reset_index()
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.285478
# 1        1                                       grade:A      1.141219
# 2        2                                       grade:B      0.885134
# 3        3                                       grade:C      0.690067
# 4        4                                       grade:D      0.502034
# 5        5                                       grade:E      0.326603
# 6        6                                       grade:F      0.136833
# 7        7                            home_ownership:OWN      0.091909
# 8        8                       home_ownership:MORTGAGE      0.106068
# 9        9                              addr_state:NM_VA      0.028894
# 10      10                                 addr_state:NY      0.051285
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12      12                                 addr_state:CA      0.057933
# 13      13                        addr_state:UT_KY_AZ_NJ      0.073062
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.130200
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.094414
# 16      16                           addr_state:GA_WA_OR      0.180150
# 17      17                              addr_state:WI_MT      0.223667
# 18      18                                 addr_state:TX      0.216846
# 19      19                              addr_state:IL_CT      0.256028
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22      22              verification_status:Not Verified      0.084616
# 23      23           verification_status:Source Verified     -0.010895
# 24      24                           purpose:credit_card      0.305107
# 25      25                    purpose:debt_consolidation      0.201227
# 26      26                    purpose:oth__med__vacation      0.217117
# 27      27           purpose:major_purch__car__home_impr      0.269177
# 28      28                         initial_list_status:w      0.054367
# 29      29                                       term:36      0.078434
# 30      30                                  emp_length:1      0.100007
# 31      31                                emp_length:2-4      0.126244
# 32      32                                emp_length:5-6      0.091491
# 33      33                                emp_length:7-9      0.061723
# 34      34                                 emp_length:10      0.125873
# 35      35                        mths_since_issue_d:<38      1.091351
# 36      36                      mths_since_issue_d:38-39      0.886866
# 37      37                      mths_since_issue_d:40-41      0.786364
# 38      38                      mths_since_issue_d:42-48      0.585583
# 39      39                      mths_since_issue_d:49-52      0.424524
# 40      40                      mths_since_issue_d:53-64      0.178538
# 41      41                      mths_since_issue_d:65-84     -0.062583
# 42      42                               int_rate:<9.548      0.872003
# 43      43                         int_rate:9.548-12.025      0.557210
# 44      44                         int_rate:12.025-15.74      0.305648
# 45      45                         int_rate:15.74-20.281      0.112880
# 46      46           mths_since_earliest_cr_line:141-164      0.054014
# 47      47           mths_since_earliest_cr_line:165-247      0.035973
# 48      48           mths_since_earliest_cr_line:248-270      0.077428
# 49      49           mths_since_earliest_cr_line:271-352      0.120513
# 50      50              mths_since_earliest_cr_line:>352      0.128505
# 51      51                              inq_last_6mths:0      0.655859
# 52      52                            inq_last_6mths:1-2      0.509582
# 53      53                            inq_last_6mths:3-6      0.299320
# 54      54                            acc_now_delinq:>=1      0.201684
# 55      55                            annual_inc:20K-30K     -0.079788
# 56      56                            annual_inc:30K-40K     -0.017641
# 57      57                            annual_inc:40K-50K      0.077229
# 58      58                            annual_inc:50K-60K      0.144130
# 59      59                            annual_inc:60K-70K      0.219688
# 60      60                            annual_inc:70K-80K      0.293108
# 61      61                            annual_inc:80K-90K      0.368871
# 62      62                           annual_inc:90K-100K      0.389257
# 63      63                          annual_inc:100K-120K      0.466807
# 64      64                          annual_inc:120K-140K      0.557062
# 65      65                              annual_inc:>140K      0.494627
# 66      66                                     dti:<=1.4      0.242920
# 67      67                                   dti:1.4-3.5      0.362306
# 68      68                                   dti:3.5-7.7      0.377527
# 69      69                                  dti:7.7-10.5      0.313164
# 70      70                                 dti:10.5-16.1      0.233756
# 71      71                                 dti:16.1-20.3      0.132411
# 72      72                                 dti:20.3-21.7      0.120198
# 73      73                                 dti:21.7-22.4      0.084503
# 74      74                                   dti:22.4-35      0.043014
# 75      75                mths_since_last_delinq:Missing      0.133271
# 76      76                   mths_since_last_delinq:4-30      0.159556
# 77      77                  mths_since_last_delinq:31-56      0.205905
# 78      78                   mths_since_last_delinq:>=57      0.158590
# 79      79                mths_since_last_record:Missing      0.214644
# 80      80                   mths_since_last_record:3-20      0.330379
# 81      81                  mths_since_last_record:21-31      0.231732
# 82      82                  mths_since_last_record:32-80      0.397450
# 83      83                  mths_since_last_record:81-86      0.044308
# 84      84                   mths_since_last_record:>=86      0.119907
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name
# 0         NaN                    Intercept
# 1      0.0000                        grade
# 2      0.0000                        grade
# 3      0.0000                        grade
# 4      0.0000                        grade
# 5      0.0000                        grade
# 6      0.0053                        grade
# 7      0.0000               home_ownership
# 8      0.0000               home_ownership
# 9      0.3668                   addr_state
# 10     0.0343                   addr_state
# 11     0.0209                   addr_state
# 12     0.0063                   addr_state
# 13     0.0034                   addr_state
# 14     0.0000                   addr_state
# 15     0.0016                   addr_state
# 16     0.0000                   addr_state
# 17     0.0000                   addr_state
# 18     0.0000                   addr_state
# 19     0.0000                   addr_state
# 20     0.0000                   addr_state
# 21     0.0000                   addr_state
# 22     0.0000          verification_status
# 23     0.4172          verification_status
# 24     0.0000                      purpose
# 25     0.0000                      purpose
# 26     0.0000                      purpose
# 27     0.0000                      purpose
# 28     0.0000          initial_list_status
# 29     0.0000                         term
# 30     0.0001                   emp_length
# 31     0.0000                   emp_length
# 32     0.0000                   emp_length
# 33     0.0030                   emp_length
# 34     0.0000                   emp_length
# 35     0.0000           mths_since_issue_d
# 36     0.0000           mths_since_issue_d
# 37     0.0000           mths_since_issue_d
# 38     0.0000           mths_since_issue_d
# 39     0.0000           mths_since_issue_d
# 40     0.0000           mths_since_issue_d
# 41     0.0314           mths_since_issue_d
# 42     0.0000                     int_rate
# 43     0.0000                     int_rate
# 44     0.0000                     int_rate
# 45     0.0001                     int_rate
# 46     0.0299  mths_since_earliest_cr_line
# 47     0.0732  mths_since_earliest_cr_line
# 48     0.0032  mths_since_earliest_cr_line
# 49     0.0000  mths_since_earliest_cr_line
# 50     0.0000  mths_since_earliest_cr_line
# 51     0.0000               inq_last_6mths
# 52     0.0000               inq_last_6mths
# 53     0.0006               inq_last_6mths
# 54     0.0556               acc_now_delinq
# 55     0.0580                   annual_inc
# 56     0.6627                   annual_inc
# 57     0.0559                   annual_inc
# 58     0.0004                   annual_inc
# 59     0.0000                   annual_inc
# 60     0.0000                   annual_inc
# 61     0.0000                   annual_inc
# 62     0.0000                   annual_inc
# 63     0.0000                   annual_inc
# 64     0.0000                   annual_inc
# 65     0.0000                   annual_inc
# 66     0.0036                          dti
# 67     0.0000                          dti
# 68     0.0000                          dti
# 69     0.0000                          dti
# 70     0.0001                          dti
# 71     0.0224                          dti
# 72     0.0476                          dti
# 73     0.1919                          dti
# 74     0.4529                          dti
# 75     0.0091       mths_since_last_delinq
# 76     0.0020       mths_since_last_delinq
# 77     0.0001       mths_since_last_delinq
# 78     0.0031       mths_since_last_delinq
# 79     0.0033       mths_since_last_record
# 80     0.0049       mths_since_last_record
# 81     0.0294       mths_since_last_record
# 82     0.0000       mths_since_last_record
# 83     0.6077       mths_since_last_record
# 84     0.1095       mths_since_last_record
# 85        NaN                        grade
# 86        NaN               home_ownership
# 87        NaN                   addr_state
# 88        NaN          verification_status
# 89        NaN                      purpose
# 90        NaN          initial_list_status
# 91        NaN                         term
# 92        NaN                   emp_length
# 93        NaN           mths_since_issue_d
# 94        NaN                     int_rate
# 95        NaN  mths_since_earliest_cr_line
# 96        NaN               inq_last_6mths
# 97        NaN               acc_now_delinq
# 98        NaN                   annual_inc
# 99        NaN                          dti
# 100       NaN       mths_since_last_delinq
# 101       NaN       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Out:
# Original feature name
# Intercept                     -1.285478
# acc_now_delinq                 0.000000
# addr_state                     0.000000
# annual_inc                    -0.079788
# dti                            0.000000
# emp_length                     0.000000
# grade                          0.000000
# home_ownership                 0.000000
# initial_list_status            0.000000
# inq_last_6mths                 0.000000
# int_rate                       0.000000
# mths_since_earliest_cr_line    0.000000
# mths_since_issue_d            -0.062583
# mths_since_last_delinq         0.000000
# mths_since_last_record         0.000000
# purpose                        0.000000
# term                           0.000000
# verification_status           -0.010895
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
min_sum_coef
# Out:
# -1.43874506223422

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Out:
# Original feature name
# Intercept                     -1.285478
# acc_now_delinq                 0.201684
# addr_state                     0.516382
# annual_inc                     0.557062
# dti                            0.377527
# emp_length                     0.126244
# grade                          1.141219
# home_ownership                 0.106068
# initial_list_status            0.054367
# inq_last_6mths                 0.655859
# int_rate                       0.872003
# mths_since_earliest_cr_line    0.128505
# mths_since_issue_d             1.091351
# mths_since_last_delinq         0.205905
# mths_since_last_record         0.397450
# purpose                        0.305107
# term                           0.078434
# verification_status            0.084616
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
max_sum_coef
# Out:
# 5.614305567019871

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
df_scorecard
# Out:
# <ipython-input-216-897c5f2a602c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.285478
# 1        1                                       grade:A      1.141219
# 2        2                                       grade:B      0.885134
# 3        3                                       grade:C      0.690067
# 4        4                                       grade:D      0.502034
# 5        5                                       grade:E      0.326603
# 6        6                                       grade:F      0.136833
# 7        7                            home_ownership:OWN      0.091909
# 8        8                       home_ownership:MORTGAGE      0.106068
# 9        9                              addr_state:NM_VA      0.028894
# 10      10                                 addr_state:NY      0.051285
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12      12                                 addr_state:CA      0.057933
# 13      13                        addr_state:UT_KY_AZ_NJ      0.073062
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.130200
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.094414
# 16      16                           addr_state:GA_WA_OR      0.180150
# 17      17                              addr_state:WI_MT      0.223667
# 18      18                                 addr_state:TX      0.216846
# 19      19                              addr_state:IL_CT      0.256028
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22      22              verification_status:Not Verified      0.084616
# 23      23           verification_status:Source Verified     -0.010895
# 24      24                           purpose:credit_card      0.305107
# 25      25                    purpose:debt_consolidation      0.201227
# 26      26                    purpose:oth__med__vacation      0.217117
# 27      27           purpose:major_purch__car__home_impr      0.269177
# 28      28                         initial_list_status:w      0.054367
# 29      29                                       term:36      0.078434
# 30      30                                  emp_length:1      0.100007
# 31      31                                emp_length:2-4      0.126244
# 32      32                                emp_length:5-6      0.091491
# 33      33                                emp_length:7-9      0.061723
# 34      34                                 emp_length:10      0.125873
# 35      35                        mths_since_issue_d:<38      1.091351
# 36      36                      mths_since_issue_d:38-39      0.886866
# 37      37                      mths_since_issue_d:40-41      0.786364
# 38      38                      mths_since_issue_d:42-48      0.585583
# 39      39                      mths_since_issue_d:49-52      0.424524
# 40      40                      mths_since_issue_d:53-64      0.178538
# 41      41                      mths_since_issue_d:65-84     -0.062583
# 42      42                               int_rate:<9.548      0.872003
# 43      43                         int_rate:9.548-12.025      0.557210
# 44      44                         int_rate:12.025-15.74      0.305648
# 45      45                         int_rate:15.74-20.281      0.112880
# 46      46           mths_since_earliest_cr_line:141-164      0.054014
# 47      47           mths_since_earliest_cr_line:165-247      0.035973
# 48      48           mths_since_earliest_cr_line:248-270      0.077428
# 49      49           mths_since_earliest_cr_line:271-352      0.120513
# 50      50              mths_since_earliest_cr_line:>352      0.128505
# 51      51                              inq_last_6mths:0      0.655859
# 52      52                            inq_last_6mths:1-2      0.509582
# 53      53                            inq_last_6mths:3-6      0.299320
# 54      54                            acc_now_delinq:>=1      0.201684
# 55      55                            annual_inc:20K-30K     -0.079788
# 56      56                            annual_inc:30K-40K     -0.017641
# 57      57                            annual_inc:40K-50K      0.077229
# 58      58                            annual_inc:50K-60K      0.144130
# 59      59                            annual_inc:60K-70K      0.219688
# 60      60                            annual_inc:70K-80K      0.293108
# 61      61                            annual_inc:80K-90K      0.368871
# 62      62                           annual_inc:90K-100K      0.389257
# 63      63                          annual_inc:100K-120K      0.466807
# 64      64                          annual_inc:120K-140K      0.557062
# 65      65                              annual_inc:>140K      0.494627
# 66      66                                     dti:<=1.4      0.242920
# 67      67                                   dti:1.4-3.5      0.362306
# 68      68                                   dti:3.5-7.7      0.377527
# 69      69                                  dti:7.7-10.5      0.313164
# 70      70                                 dti:10.5-16.1      0.233756
# 71      71                                 dti:16.1-20.3      0.132411
# 72      72                                 dti:20.3-21.7      0.120198
# 73      73                                 dti:21.7-22.4      0.084503
# 74      74                                   dti:22.4-35      0.043014
# 75      75                mths_since_last_delinq:Missing      0.133271
# 76      76                   mths_since_last_delinq:4-30      0.159556
# 77      77                  mths_since_last_delinq:31-56      0.205905
# 78      78                   mths_since_last_delinq:>=57      0.158590
# 79      79                mths_since_last_record:Missing      0.214644
# 80      80                   mths_since_last_record:3-20      0.330379
# 81      81                  mths_since_last_record:21-31      0.231732
# 82      82                  mths_since_last_record:32-80      0.397450
# 83      83                  mths_since_last_record:81-86      0.044308
# 84      84                   mths_since_last_record:>=86      0.119907
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           311.951799
# 1      0.0000                        grade            88.992791
# 2      0.0000                        grade            69.023148
# 3      0.0000                        grade            53.811749
# 4      0.0000                        grade            39.148859
# 5      0.0000                        grade            25.468641
# 6      0.0053                        grade            10.670261
# 7      0.0000               home_ownership             7.167110
# 8      0.0000               home_ownership             8.271196
# 9      0.3668                   addr_state             2.253133
# 10     0.0343                   addr_state             3.999253
# 11     0.0209                   addr_state             4.170841
# 12     0.0063                   addr_state             4.517676
# 13     0.0034                   addr_state             5.697428
# 14     0.0000                   addr_state            10.153041
# 15     0.0016                   addr_state             7.362448
# 16     0.0000                   addr_state            14.048179
# 17     0.0000                   addr_state            17.441650
# 18     0.0000                   addr_state            16.909772
# 19     0.0000                   addr_state            19.965157
# 20     0.0000                   addr_state            24.556585
# 21     0.0000                   addr_state            40.267735
# 22     0.0000          verification_status             6.598361
# 23     0.4172          verification_status            -0.849634
# 24     0.0000                      purpose            23.792393
# 25     0.0000                      purpose            15.691784
# 26     0.0000                      purpose            16.930918
# 27     0.0000                      purpose            20.990504
# 28     0.0000          initial_list_status             4.239578
# 29     0.0000                         term             6.116339
# 30     0.0001                   emp_length             7.798587
# 31     0.0000                   emp_length             9.844571
# 32     0.0000                   emp_length             7.134547
# 33     0.0030                   emp_length             4.813150
# 34     0.0000                   emp_length             9.815606
# 35     0.0000           mths_since_issue_d            85.104046
# 36     0.0000           mths_since_issue_d            69.158232
# 37     0.0000           mths_since_issue_d            61.320977
# 38     0.0000           mths_since_issue_d            45.664021
# 39     0.0000           mths_since_issue_d            33.104543
# 40     0.0000           mths_since_issue_d            13.922485
# 41     0.0314           mths_since_issue_d            -4.880250
# 42     0.0000                     int_rate            67.999204
# 43     0.0000                     int_rate            43.451447
# 44     0.0000                     int_rate            23.834599
# 45     0.0001                     int_rate             8.802404
# 46     0.0299  mths_since_earliest_cr_line             4.212063
# 47     0.0732  mths_since_earliest_cr_line             2.805177
# 48     0.0032  mths_since_earliest_cr_line             6.037879
# 49     0.0000  mths_since_earliest_cr_line             9.397675
# 50     0.0000  mths_since_earliest_cr_line            10.020882
# 51     0.0000               inq_last_6mths            51.144166
# 52     0.0000               inq_last_6mths            39.737400
# 53     0.0006               inq_last_6mths            23.341100
# 54     0.0556               acc_now_delinq            15.727428
# 55     0.0580                   annual_inc            -6.221915
# 56     0.6627                   annual_inc            -1.375629
# 57     0.0559                   annual_inc             6.022357
# 58     0.0004                   annual_inc            11.239343
# 59     0.0000                   annual_inc            17.131346
# 60     0.0000                   annual_inc            22.856656
# 61     0.0000                   annual_inc            28.764738
# 62     0.0000                   annual_inc            30.354424
# 63     0.0000                   annual_inc            36.401781
# 64     0.0000                   annual_inc            43.439948
# 65     0.0000                   annual_inc            38.571218
# 66     0.0036                          dti            18.943036
# 67     0.0000                          dti            28.252808
# 68     0.0000                          dti            29.439702
# 69     0.0000                          dti            24.420630
# 70     0.0001                          dti            18.228367
# 71     0.0224                          dti            10.325457
# 72     0.0476                          dti             9.373062
# 73     0.1919                          dti             6.589549
# 74     0.4529                          dti             3.354253
# 75     0.0091       mths_since_last_delinq            10.392517
# 76     0.0020       mths_since_last_delinq            12.442264
# 77     0.0001       mths_since_last_delinq            16.056557
# 78     0.0031       mths_since_last_delinq            12.366920
# 79     0.0033       mths_since_last_record            16.738013
# 80     0.0049       mths_since_last_record            25.763091
# 81     0.0294       mths_since_last_record            18.070560
# 82     0.0000       mths_since_last_record            30.993305
# 83     0.6077       mths_since_last_record             3.455124
# 84     0.1095       mths_since_last_record             9.350398
# 85        NaN                        grade             0.000000
# 86        NaN               home_ownership             0.000000
# 87        NaN                   addr_state             0.000000
# 88        NaN          verification_status             0.000000
# 89        NaN                      purpose             0.000000
# 90        NaN          initial_list_status             0.000000
# 91        NaN                         term             0.000000
# 92        NaN                   emp_length             0.000000
# 93        NaN           mths_since_issue_d             0.000000
# 94        NaN                     int_rate             0.000000
# 95        NaN  mths_since_earliest_cr_line             0.000000
# 96        NaN               inq_last_6mths             0.000000
# 97        NaN               acc_now_delinq             0.000000
# 98        NaN                   annual_inc             0.000000
# 99        NaN                          dti             0.000000
# 100       NaN       mths_since_last_delinq             0.000000
# 101       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary
# 0                  312.0
# 1                   89.0
# 2                   69.0
# 3                   54.0
# 4                   39.0
# 5                   25.0
# 6                   11.0
# 7                    7.0
# 8                    8.0
# 9                    2.0
# 10                   4.0
# 11                   4.0
# 12                   5.0
# 13                   6.0
# 14                  10.0
# 15                   7.0
# 16                  14.0
# 17                  17.0
# 18                  17.0
# 19                  20.0
# 20                  25.0
# 21                  40.0
# 22                   7.0
# 23                  -1.0
# 24                  24.0
# 25                  16.0
# 26                  17.0
# 27                  21.0
# 28                   4.0
# 29                   6.0
# 30                   8.0
# 31                  10.0
# 32                   7.0
# 33                   5.0
# 34                  10.0
# 35                  85.0
# 36                  69.0
# 37                  61.0
# 38                  46.0
# 39                  33.0
# 40                  14.0
# 41                  -5.0
# 42                  68.0
# 43                  43.0
# 44                  24.0
# 45                   9.0
# 46                   4.0
# 47                   3.0
# 48                   6.0
# 49                   9.0
# 50                  10.0
# 51                  51.0
# 52                  40.0
# 53                  23.0
# 54                  16.0
# 55                  -6.0
# 56                  -1.0
# 57                   6.0
# 58                  11.0
# 59                  17.0
# 60                  23.0
# 61                  29.0
# 62                  30.0
# 63                  36.0
# 64                  43.0
# 65                  39.0
# 66                  19.0
# 67                  28.0
# 68                  29.0
# 69                  24.0
# 70                  18.0
# 71                  10.0
# 72                   9.0
# 73                   7.0
# 74                   3.0
# 75                  10.0
# 76                  12.0
# 77                  16.0
# 78                  12.0
# 79                  17.0
# 80                  26.0
# 81                  18.0
# 82                  31.0
# 83                   3.0
# 84                   9.0
# 85                   0.0
# 86                   0.0
# 87                   0.0
# 88                   0.0
# 89                   0.0
# 90                   0.0
# 91                   0.0
# 92                   0.0
# 93                   0.0
# 94                   0.0
# 95                   0.0
# 96                   0.0
# 97                   0.0
# 98                   0.0
# 99                   0.0
# 100                  0.0
# 101                  0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
max_sum_score_prel
# Out:
# 849.0

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][77] = 16
df_scorecard
# Out:
# <ipython-input-219-f4f54c309bab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][77] = 16
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.285478
# 1        1                                       grade:A      1.141219
# 2        2                                       grade:B      0.885134
# 3        3                                       grade:C      0.690067
# 4        4                                       grade:D      0.502034
# 5        5                                       grade:E      0.326603
# 6        6                                       grade:F      0.136833
# 7        7                            home_ownership:OWN      0.091909
# 8        8                       home_ownership:MORTGAGE      0.106068
# 9        9                              addr_state:NM_VA      0.028894
# 10      10                                 addr_state:NY      0.051285
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12      12                                 addr_state:CA      0.057933
# 13      13                        addr_state:UT_KY_AZ_NJ      0.073062
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.130200
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.094414
# 16      16                           addr_state:GA_WA_OR      0.180150
# 17      17                              addr_state:WI_MT      0.223667
# 18      18                                 addr_state:TX      0.216846
# 19      19                              addr_state:IL_CT      0.256028
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22      22              verification_status:Not Verified      0.084616
# 23      23           verification_status:Source Verified     -0.010895
# 24      24                           purpose:credit_card      0.305107
# 25      25                    purpose:debt_consolidation      0.201227
# 26      26                    purpose:oth__med__vacation      0.217117
# 27      27           purpose:major_purch__car__home_impr      0.269177
# 28      28                         initial_list_status:w      0.054367
# 29      29                                       term:36      0.078434
# 30      30                                  emp_length:1      0.100007
# 31      31                                emp_length:2-4      0.126244
# 32      32                                emp_length:5-6      0.091491
# 33      33                                emp_length:7-9      0.061723
# 34      34                                 emp_length:10      0.125873
# 35      35                        mths_since_issue_d:<38      1.091351
# 36      36                      mths_since_issue_d:38-39      0.886866
# 37      37                      mths_since_issue_d:40-41      0.786364
# 38      38                      mths_since_issue_d:42-48      0.585583
# 39      39                      mths_since_issue_d:49-52      0.424524
# 40      40                      mths_since_issue_d:53-64      0.178538
# 41      41                      mths_since_issue_d:65-84     -0.062583
# 42      42                               int_rate:<9.548      0.872003
# 43      43                         int_rate:9.548-12.025      0.557210
# 44      44                         int_rate:12.025-15.74      0.305648
# 45      45                         int_rate:15.74-20.281      0.112880
# 46      46           mths_since_earliest_cr_line:141-164      0.054014
# 47      47           mths_since_earliest_cr_line:165-247      0.035973
# 48      48           mths_since_earliest_cr_line:248-270      0.077428
# 49      49           mths_since_earliest_cr_line:271-352      0.120513
# 50      50              mths_since_earliest_cr_line:>352      0.128505
# 51      51                              inq_last_6mths:0      0.655859
# 52      52                            inq_last_6mths:1-2      0.509582
# 53      53                            inq_last_6mths:3-6      0.299320
# 54      54                            acc_now_delinq:>=1      0.201684
# 55      55                            annual_inc:20K-30K     -0.079788
# 56      56                            annual_inc:30K-40K     -0.017641
# 57      57                            annual_inc:40K-50K      0.077229
# 58      58                            annual_inc:50K-60K      0.144130
# 59      59                            annual_inc:60K-70K      0.219688
# 60      60                            annual_inc:70K-80K      0.293108
# 61      61                            annual_inc:80K-90K      0.368871
# 62      62                           annual_inc:90K-100K      0.389257
# 63      63                          annual_inc:100K-120K      0.466807
# 64      64                          annual_inc:120K-140K      0.557062
# 65      65                              annual_inc:>140K      0.494627
# 66      66                                     dti:<=1.4      0.242920
# 67      67                                   dti:1.4-3.5      0.362306
# 68      68                                   dti:3.5-7.7      0.377527
# 69      69                                  dti:7.7-10.5      0.313164
# 70      70                                 dti:10.5-16.1      0.233756
# 71      71                                 dti:16.1-20.3      0.132411
# 72      72                                 dti:20.3-21.7      0.120198
# 73      73                                 dti:21.7-22.4      0.084503
# 74      74                                   dti:22.4-35      0.043014
# 75      75                mths_since_last_delinq:Missing      0.133271
# 76      76                   mths_since_last_delinq:4-30      0.159556
# 77      77                  mths_since_last_delinq:31-56      0.205905
# 78      78                   mths_since_last_delinq:>=57      0.158590
# 79      79                mths_since_last_record:Missing      0.214644
# 80      80                   mths_since_last_record:3-20      0.330379
# 81      81                  mths_since_last_record:21-31      0.231732
# 82      82                  mths_since_last_record:32-80      0.397450
# 83      83                  mths_since_last_record:81-86      0.044308
# 84      84                   mths_since_last_record:>=86      0.119907
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           311.951799
# 1      0.0000                        grade            88.992791
# 2      0.0000                        grade            69.023148
# 3      0.0000                        grade            53.811749
# 4      0.0000                        grade            39.148859
# 5      0.0000                        grade            25.468641
# 6      0.0053                        grade            10.670261
# 7      0.0000               home_ownership             7.167110
# 8      0.0000               home_ownership             8.271196
# 9      0.3668                   addr_state             2.253133
# 10     0.0343                   addr_state             3.999253
# 11     0.0209                   addr_state             4.170841
# 12     0.0063                   addr_state             4.517676
# 13     0.0034                   addr_state             5.697428
# 14     0.0000                   addr_state            10.153041
# 15     0.0016                   addr_state             7.362448
# 16     0.0000                   addr_state            14.048179
# 17     0.0000                   addr_state            17.441650
# 18     0.0000                   addr_state            16.909772
# 19     0.0000                   addr_state            19.965157
# 20     0.0000                   addr_state            24.556585
# 21     0.0000                   addr_state            40.267735
# 22     0.0000          verification_status             6.598361
# 23     0.4172          verification_status            -0.849634
# 24     0.0000                      purpose            23.792393
# 25     0.0000                      purpose            15.691784
# 26     0.0000                      purpose            16.930918
# 27     0.0000                      purpose            20.990504
# 28     0.0000          initial_list_status             4.239578
# 29     0.0000                         term             6.116339
# 30     0.0001                   emp_length             7.798587
# 31     0.0000                   emp_length             9.844571
# 32     0.0000                   emp_length             7.134547
# 33     0.0030                   emp_length             4.813150
# 34     0.0000                   emp_length             9.815606
# 35     0.0000           mths_since_issue_d            85.104046
# 36     0.0000           mths_since_issue_d            69.158232
# 37     0.0000           mths_since_issue_d            61.320977
# 38     0.0000           mths_since_issue_d            45.664021
# 39     0.0000           mths_since_issue_d            33.104543
# 40     0.0000           mths_since_issue_d            13.922485
# 41     0.0314           mths_since_issue_d            -4.880250
# 42     0.0000                     int_rate            67.999204
# 43     0.0000                     int_rate            43.451447
# 44     0.0000                     int_rate            23.834599
# 45     0.0001                     int_rate             8.802404
# 46     0.0299  mths_since_earliest_cr_line             4.212063
# 47     0.0732  mths_since_earliest_cr_line             2.805177
# 48     0.0032  mths_since_earliest_cr_line             6.037879
# 49     0.0000  mths_since_earliest_cr_line             9.397675
# 50     0.0000  mths_since_earliest_cr_line            10.020882
# 51     0.0000               inq_last_6mths            51.144166
# 52     0.0000               inq_last_6mths            39.737400
# 53     0.0006               inq_last_6mths            23.341100
# 54     0.0556               acc_now_delinq            15.727428
# 55     0.0580                   annual_inc            -6.221915
# 56     0.6627                   annual_inc            -1.375629
# 57     0.0559                   annual_inc             6.022357
# 58     0.0004                   annual_inc            11.239343
# 59     0.0000                   annual_inc            17.131346
# 60     0.0000                   annual_inc            22.856656
# 61     0.0000                   annual_inc            28.764738
# 62     0.0000                   annual_inc            30.354424
# 63     0.0000                   annual_inc            36.401781
# 64     0.0000                   annual_inc            43.439948
# 65     0.0000                   annual_inc            38.571218
# 66     0.0036                          dti            18.943036
# 67     0.0000                          dti            28.252808
# 68     0.0000                          dti            29.439702
# 69     0.0000                          dti            24.420630
# 70     0.0001                          dti            18.228367
# 71     0.0224                          dti            10.325457
# 72     0.0476                          dti             9.373062
# 73     0.1919                          dti             6.589549
# 74     0.4529                          dti             3.354253
# 75     0.0091       mths_since_last_delinq            10.392517
# 76     0.0020       mths_since_last_delinq            12.442264
# 77     0.0001       mths_since_last_delinq            16.056557
# 78     0.0031       mths_since_last_delinq            12.366920
# 79     0.0033       mths_since_last_record            16.738013
# 80     0.0049       mths_since_last_record            25.763091
# 81     0.0294       mths_since_last_record            18.070560
# 82     0.0000       mths_since_last_record            30.993305
# 83     0.6077       mths_since_last_record             3.455124
# 84     0.1095       mths_since_last_record             9.350398
# 85        NaN                        grade             0.000000
# 86        NaN               home_ownership             0.000000
# 87        NaN                   addr_state             0.000000
# 88        NaN          verification_status             0.000000
# 89        NaN                      purpose             0.000000
# 90        NaN          initial_list_status             0.000000
# 91        NaN                         term             0.000000
# 92        NaN                   emp_length             0.000000
# 93        NaN           mths_since_issue_d             0.000000
# 94        NaN                     int_rate             0.000000
# 95        NaN  mths_since_earliest_cr_line             0.000000
# 96        NaN               inq_last_6mths             0.000000
# 97        NaN               acc_now_delinq             0.000000
# 98        NaN                   annual_inc             0.000000
# 99        NaN                          dti             0.000000
# 100       NaN       mths_since_last_delinq             0.000000
# 101       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  312.0    0.048201          312.0
# 1                   89.0    0.007209           89.0
# 2                   69.0   -0.023148           69.0
# 3                   54.0    0.188251           54.0
# 4                   39.0   -0.148859           39.0
# 5                   25.0   -0.468641           25.0
# 6                   11.0    0.329739           11.0
# 7                    7.0   -0.167110            7.0
# 8                    8.0   -0.271196            8.0
# 9                    2.0   -0.253133            2.0
# 10                   4.0    0.000747            4.0
# 11                   4.0   -0.170841            4.0
# 12                   5.0    0.482324            5.0
# 13                   6.0    0.302572            6.0
# 14                  10.0   -0.153041           10.0
# 15                   7.0   -0.362448            7.0
# 16                  14.0   -0.048179           14.0
# 17                  17.0   -0.441650           17.0
# 18                  17.0    0.090228           17.0
# 19                  20.0    0.034843           20.0
# 20                  25.0    0.443415           25.0
# 21                  40.0   -0.267735           40.0
# 22                   7.0    0.401639            7.0
# 23                  -1.0   -0.150366           -1.0
# 24                  24.0    0.207607           24.0
# 25                  16.0    0.308216           16.0
# 26                  17.0    0.069082           17.0
# 27                  21.0    0.009496           21.0
# 28                   4.0   -0.239578            4.0
# 29                   6.0   -0.116339            6.0
# 30                   8.0    0.201413            8.0
# 31                  10.0    0.155429           10.0
# 32                   7.0   -0.134547            7.0
# 33                   5.0    0.186850            5.0
# 34                  10.0    0.184394           10.0
# 35                  85.0   -0.104046           85.0
# 36                  69.0   -0.158232           69.0
# 37                  61.0   -0.320977           61.0
# 38                  46.0    0.335979           46.0
# 39                  33.0   -0.104543           33.0
# 40                  14.0    0.077515           14.0
# 41                  -5.0   -0.119750           -5.0
# 42                  68.0    0.000796           68.0
# 43                  43.0   -0.451447           43.0
# 44                  24.0    0.165401           24.0
# 45                   9.0    0.197596            9.0
# 46                   4.0   -0.212063            4.0
# 47                   3.0    0.194823            3.0
# 48                   6.0   -0.037879            6.0
# 49                   9.0   -0.397675            9.0
# 50                  10.0   -0.020882           10.0
# 51                  51.0   -0.144166           51.0
# 52                  40.0    0.262600           40.0
# 53                  23.0   -0.341100           23.0
# 54                  16.0    0.272572           16.0
# 55                  -6.0    0.221915           -6.0
# 56                  -1.0    0.375629           -1.0
# 57                   6.0   -0.022357            6.0
# 58                  11.0   -0.239343           11.0
# 59                  17.0   -0.131346           17.0
# 60                  23.0    0.143344           23.0
# 61                  29.0    0.235262           29.0
# 62                  30.0   -0.354424           30.0
# 63                  36.0   -0.401781           36.0
# 64                  43.0   -0.439948           43.0
# 65                  39.0    0.428782           39.0
# 66                  19.0    0.056964           19.0
# 67                  28.0   -0.252808           28.0
# 68                  29.0   -0.439702           29.0
# 69                  24.0   -0.420630           24.0
# 70                  18.0   -0.228367           18.0
# 71                  10.0   -0.325457           10.0
# 72                   9.0   -0.373062            9.0
# 73                   7.0    0.410451            7.0
# 74                   3.0   -0.354253            3.0
# 75                  10.0   -0.392517           10.0
# 76                  12.0   -0.442264           12.0
# 77                  16.0   -0.056557           16.0
# 78                  12.0   -0.366920           12.0
# 79                  17.0    0.261987           17.0
# 80                  26.0    0.236909           26.0
# 81                  18.0   -0.070560           18.0
# 82                  31.0    0.006695           31.0
# 83                   3.0   -0.455124            3.0
# 84                   9.0   -0.350398            9.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0
# 101                  0.0    0.000000            0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max().sum()
max_sum_score_prel
# Out:
# 849.0

# %% [markdown]
# # Calculating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.285478
# 1        1                                       grade:A      1.141219
# 2        2                                       grade:B      0.885134
# 3        3                                       grade:C      0.690067
# 4        4                                       grade:D      0.502034
# 5        5                                       grade:E      0.326603
# 6        6                                       grade:F      0.136833
# 7        7                            home_ownership:OWN      0.091909
# 8        8                       home_ownership:MORTGAGE      0.106068
# 9        9                              addr_state:NM_VA      0.028894
# 10      10                                 addr_state:NY      0.051285
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12      12                                 addr_state:CA      0.057933
# 13      13                        addr_state:UT_KY_AZ_NJ      0.073062
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.130200
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.094414
# 16      16                           addr_state:GA_WA_OR      0.180150
# 17      17                              addr_state:WI_MT      0.223667
# 18      18                                 addr_state:TX      0.216846
# 19      19                              addr_state:IL_CT      0.256028
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22      22              verification_status:Not Verified      0.084616
# 23      23           verification_status:Source Verified     -0.010895
# 24      24                           purpose:credit_card      0.305107
# 25      25                    purpose:debt_consolidation      0.201227
# 26      26                    purpose:oth__med__vacation      0.217117
# 27      27           purpose:major_purch__car__home_impr      0.269177
# 28      28                         initial_list_status:w      0.054367
# 29      29                                       term:36      0.078434
# 30      30                                  emp_length:1      0.100007
# 31      31                                emp_length:2-4      0.126244
# 32      32                                emp_length:5-6      0.091491
# 33      33                                emp_length:7-9      0.061723
# 34      34                                 emp_length:10      0.125873
# 35      35                        mths_since_issue_d:<38      1.091351
# 36      36                      mths_since_issue_d:38-39      0.886866
# 37      37                      mths_since_issue_d:40-41      0.786364
# 38      38                      mths_since_issue_d:42-48      0.585583
# 39      39                      mths_since_issue_d:49-52      0.424524
# 40      40                      mths_since_issue_d:53-64      0.178538
# 41      41                      mths_since_issue_d:65-84     -0.062583
# 42      42                               int_rate:<9.548      0.872003
# 43      43                         int_rate:9.548-12.025      0.557210
# 44      44                         int_rate:12.025-15.74      0.305648
# 45      45                         int_rate:15.74-20.281      0.112880
# 46      46           mths_since_earliest_cr_line:141-164      0.054014
# 47      47           mths_since_earliest_cr_line:165-247      0.035973
# 48      48           mths_since_earliest_cr_line:248-270      0.077428
# 49      49           mths_since_earliest_cr_line:271-352      0.120513
# 50      50              mths_since_earliest_cr_line:>352      0.128505
# 51      51                              inq_last_6mths:0      0.655859
# 52      52                            inq_last_6mths:1-2      0.509582
# 53      53                            inq_last_6mths:3-6      0.299320
# 54      54                            acc_now_delinq:>=1      0.201684
# 55      55                            annual_inc:20K-30K     -0.079788
# 56      56                            annual_inc:30K-40K     -0.017641
# 57      57                            annual_inc:40K-50K      0.077229
# 58      58                            annual_inc:50K-60K      0.144130
# 59      59                            annual_inc:60K-70K      0.219688
# 60      60                            annual_inc:70K-80K      0.293108
# 61      61                            annual_inc:80K-90K      0.368871
# 62      62                           annual_inc:90K-100K      0.389257
# 63      63                          annual_inc:100K-120K      0.466807
# 64      64                          annual_inc:120K-140K      0.557062
# 65      65                              annual_inc:>140K      0.494627
# 66      66                                     dti:<=1.4      0.242920
# 67      67                                   dti:1.4-3.5      0.362306
# 68      68                                   dti:3.5-7.7      0.377527
# 69      69                                  dti:7.7-10.5      0.313164
# 70      70                                 dti:10.5-16.1      0.233756
# 71      71                                 dti:16.1-20.3      0.132411
# 72      72                                 dti:20.3-21.7      0.120198
# 73      73                                 dti:21.7-22.4      0.084503
# 74      74                                   dti:22.4-35      0.043014
# 75      75                mths_since_last_delinq:Missing      0.133271
# 76      76                   mths_since_last_delinq:4-30      0.159556
# 77      77                  mths_since_last_delinq:31-56      0.205905
# 78      78                   mths_since_last_delinq:>=57      0.158590
# 79      79                mths_since_last_record:Missing      0.214644
# 80      80                   mths_since_last_record:3-20      0.330379
# 81      81                  mths_since_last_record:21-31      0.231732
# 82      82                  mths_since_last_record:32-80      0.397450
# 83      83                  mths_since_last_record:81-86      0.044308
# 84      84                   mths_since_last_record:>=86      0.119907
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           311.951799
# 1      0.0000                        grade            88.992791
# 2      0.0000                        grade            69.023148
# 3      0.0000                        grade            53.811749
# 4      0.0000                        grade            39.148859
# 5      0.0000                        grade            25.468641
# 6      0.0053                        grade            10.670261
# 7      0.0000               home_ownership             7.167110
# 8      0.0000               home_ownership             8.271196
# 9      0.3668                   addr_state             2.253133
# 10     0.0343                   addr_state             3.999253
# 11     0.0209                   addr_state             4.170841
# 12     0.0063                   addr_state             4.517676
# 13     0.0034                   addr_state             5.697428
# 14     0.0000                   addr_state            10.153041
# 15     0.0016                   addr_state             7.362448
# 16     0.0000                   addr_state            14.048179
# 17     0.0000                   addr_state            17.441650
# 18     0.0000                   addr_state            16.909772
# 19     0.0000                   addr_state            19.965157
# 20     0.0000                   addr_state            24.556585
# 21     0.0000                   addr_state            40.267735
# 22     0.0000          verification_status             6.598361
# 23     0.4172          verification_status            -0.849634
# 24     0.0000                      purpose            23.792393
# 25     0.0000                      purpose            15.691784
# 26     0.0000                      purpose            16.930918
# 27     0.0000                      purpose            20.990504
# 28     0.0000          initial_list_status             4.239578
# 29     0.0000                         term             6.116339
# 30     0.0001                   emp_length             7.798587
# 31     0.0000                   emp_length             9.844571
# 32     0.0000                   emp_length             7.134547
# 33     0.0030                   emp_length             4.813150
# 34     0.0000                   emp_length             9.815606
# 35     0.0000           mths_since_issue_d            85.104046
# 36     0.0000           mths_since_issue_d            69.158232
# 37     0.0000           mths_since_issue_d            61.320977
# 38     0.0000           mths_since_issue_d            45.664021
# 39     0.0000           mths_since_issue_d            33.104543
# 40     0.0000           mths_since_issue_d            13.922485
# 41     0.0314           mths_since_issue_d            -4.880250
# 42     0.0000                     int_rate            67.999204
# 43     0.0000                     int_rate            43.451447
# 44     0.0000                     int_rate            23.834599
# 45     0.0001                     int_rate             8.802404
# 46     0.0299  mths_since_earliest_cr_line             4.212063
# 47     0.0732  mths_since_earliest_cr_line             2.805177
# 48     0.0032  mths_since_earliest_cr_line             6.037879
# 49     0.0000  mths_since_earliest_cr_line             9.397675
# 50     0.0000  mths_since_earliest_cr_line            10.020882
# 51     0.0000               inq_last_6mths            51.144166
# 52     0.0000               inq_last_6mths            39.737400
# 53     0.0006               inq_last_6mths            23.341100
# 54     0.0556               acc_now_delinq            15.727428
# 55     0.0580                   annual_inc            -6.221915
# 56     0.6627                   annual_inc            -1.375629
# 57     0.0559                   annual_inc             6.022357
# 58     0.0004                   annual_inc            11.239343
# 59     0.0000                   annual_inc            17.131346
# 60     0.0000                   annual_inc            22.856656
# 61     0.0000                   annual_inc            28.764738
# 62     0.0000                   annual_inc            30.354424
# 63     0.0000                   annual_inc            36.401781
# 64     0.0000                   annual_inc            43.439948
# 65     0.0000                   annual_inc            38.571218
# 66     0.0036                          dti            18.943036
# 67     0.0000                          dti            28.252808
# 68     0.0000                          dti            29.439702
# 69     0.0000                          dti            24.420630
# 70     0.0001                          dti            18.228367
# 71     0.0224                          dti            10.325457
# 72     0.0476                          dti             9.373062
# 73     0.1919                          dti             6.589549
# 74     0.4529                          dti             3.354253
# 75     0.0091       mths_since_last_delinq            10.392517
# 76     0.0020       mths_since_last_delinq            12.442264
# 77     0.0001       mths_since_last_delinq            16.056557
# 78     0.0031       mths_since_last_delinq            12.366920
# 79     0.0033       mths_since_last_record            16.738013
# 80     0.0049       mths_since_last_record            25.763091
# 81     0.0294       mths_since_last_record            18.070560
# 82     0.0000       mths_since_last_record            30.993305
# 83     0.6077       mths_since_last_record             3.455124
# 84     0.1095       mths_since_last_record             9.350398
# 85        NaN                        grade             0.000000
# 86        NaN               home_ownership             0.000000
# 87        NaN                   addr_state             0.000000
# 88        NaN          verification_status             0.000000
# 89        NaN                      purpose             0.000000
# 90        NaN          initial_list_status             0.000000
# 91        NaN                         term             0.000000
# 92        NaN                   emp_length             0.000000
# 93        NaN           mths_since_issue_d             0.000000
# 94        NaN                     int_rate             0.000000
# 95        NaN  mths_since_earliest_cr_line             0.000000
# 96        NaN               inq_last_6mths             0.000000
# 97        NaN               acc_now_delinq             0.000000
# 98        NaN                   annual_inc             0.000000
# 99        NaN                          dti             0.000000
# 100       NaN       mths_since_last_delinq             0.000000
# 101       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  312.0    0.048201          312.0
# 1                   89.0    0.007209           89.0
# 2                   69.0   -0.023148           69.0
# 3                   54.0    0.188251           54.0
# 4                   39.0   -0.148859           39.0
# 5                   25.0   -0.468641           25.0
# 6                   11.0    0.329739           11.0
# 7                    7.0   -0.167110            7.0
# 8                    8.0   -0.271196            8.0
# 9                    2.0   -0.253133            2.0
# 10                   4.0    0.000747            4.0
# 11                   4.0   -0.170841            4.0
# 12                   5.0    0.482324            5.0
# 13                   6.0    0.302572            6.0
# 14                  10.0   -0.153041           10.0
# 15                   7.0   -0.362448            7.0
# 16                  14.0   -0.048179           14.0
# 17                  17.0   -0.441650           17.0
# 18                  17.0    0.090228           17.0
# 19                  20.0    0.034843           20.0
# 20                  25.0    0.443415           25.0
# 21                  40.0   -0.267735           40.0
# 22                   7.0    0.401639            7.0
# 23                  -1.0   -0.150366           -1.0
# 24                  24.0    0.207607           24.0
# 25                  16.0    0.308216           16.0
# 26                  17.0    0.069082           17.0
# 27                  21.0    0.009496           21.0
# 28                   4.0   -0.239578            4.0
# 29                   6.0   -0.116339            6.0
# 30                   8.0    0.201413            8.0
# 31                  10.0    0.155429           10.0
# 32                   7.0   -0.134547            7.0
# 33                   5.0    0.186850            5.0
# 34                  10.0    0.184394           10.0
# 35                  85.0   -0.104046           85.0
# 36                  69.0   -0.158232           69.0
# 37                  61.0   -0.320977           61.0
# 38                  46.0    0.335979           46.0
# 39                  33.0   -0.104543           33.0
# 40                  14.0    0.077515           14.0
# 41                  -5.0   -0.119750           -5.0
# 42                  68.0    0.000796           68.0
# 43                  43.0   -0.451447           43.0
# 44                  24.0    0.165401           24.0
# 45                   9.0    0.197596            9.0
# 46                   4.0   -0.212063            4.0
# 47                   3.0    0.194823            3.0
# 48                   6.0   -0.037879            6.0
# 49                   9.0   -0.397675            9.0
# 50                  10.0   -0.020882           10.0
# 51                  51.0   -0.144166           51.0
# 52                  40.0    0.262600           40.0
# 53                  23.0   -0.341100           23.0
# 54                  16.0    0.272572           16.0
# 55                  -6.0    0.221915           -6.0
# 56                  -1.0    0.375629           -1.0
# 57                   6.0   -0.022357            6.0
# 58                  11.0   -0.239343           11.0
# 59                  17.0   -0.131346           17.0
# 60                  23.0    0.143344           23.0
# 61                  29.0    0.235262           29.0
# 62                  30.0   -0.354424           30.0
# 63                  36.0   -0.401781           36.0
# 64                  43.0   -0.439948           43.0
# 65                  39.0    0.428782           39.0
# 66                  19.0    0.056964           19.0
# 67                  28.0   -0.252808           28.0
# 68                  29.0   -0.439702           29.0
# 69                  24.0   -0.420630           24.0
# 70                  18.0   -0.228367           18.0
# 71                  10.0   -0.325457           10.0
# 72                   9.0   -0.373062            9.0
# 73                   7.0    0.410451            7.0
# 74                   3.0   -0.354253            3.0
# 75                  10.0   -0.392517           10.0
# 76                  12.0   -0.442264           12.0
# 77                  16.0   -0.056557           16.0
# 78                  12.0   -0.366920           12.0
# 79                  17.0    0.261987           17.0
# 80                  26.0    0.236909           26.0
# 81                  18.0   -0.070560           18.0
# 82                  31.0    0.006695           31.0
# 83                   3.0   -0.455124            3.0
# 84                   9.0   -0.350398            9.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0
# 101                  0.0    0.000000            0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]
scorecard_scores = df_scorecard['Score - Final']
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 102)

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      1                      0
# 288564                      0                      0
# 213591                      1                      0
# 263083                      1                      0
# 165001                      0                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0              0            0
# 288564              0              0              0            1
# 213591              0              0              0            0
# 263083              1              0              0            0
# 165001              0              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86  grade:G  \
# 362514                             0                            0        0
# 288564                             0                            0        0
# 213591                             0                            0        0
# 263083                             0                            0        0
# 165001                             0                            0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                                   0                                0
# 288564                                   0                                0
# 213591                                   0                                0
# 263083                                   0                                0
# 165001                                   0                                0
#
#         verification_status:Verified  \
# 362514                             1
# 288564                             1
# 213591                             1
# 263083                             0
# 165001                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 362514                                             0                      1
# 288564                                             0                      0
# 213591                                             0                      1
# 263083                                             0                      0
# 165001                                             0                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 362514        1             1                       0                 0
# 288564        1             0                       0                 1
# 213591        0             0                       0                 0
# 263083        1             0                       0                 0
# 165001        0             0                       0                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                                 0                  0                 1
# 288564                                 0                  0                 1
# 213591                                 0                  0                 1
# 263083                                 1                  0                 1
# 165001                                 0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 362514                0        0                           0
# 288564                0        0                           1
# 213591                0        0                           0
# 263083                0        0                           0
# 165001                0        0                           0
#
#         mths_since_last_record:0-2
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
scorecard_scores = scorecard_scores.values.reshape(102, 1)
scorecard_scores.shape
# Out:
# (102, 1)

# %% [markdown]
# ### Generating score for test data

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)
y_scores.head()
# Out:
#             0
# 362514  607.0
# 288564  544.0
# 213591  573.0
# 263083  627.0
# 165001  680.0

# %% [markdown]
# ### Generating Final Scorecard (Easy to use)

# %%
final_scorecard = pd.DataFrame(scorecard_scores, 
                               columns = ['Score'],
                               index = [df_scorecard['Feature name'].values])
final_scorecard
# Out:
#                                               Score
# Intercept                                     312.0
# grade:A                                        89.0
# grade:B                                        69.0
# grade:C                                        54.0
# grade:D                                        39.0
# grade:E                                        25.0
# grade:F                                        11.0
# home_ownership:OWN                              7.0
# home_ownership:MORTGAGE                         8.0
# addr_state:NM_VA                                2.0
# addr_state:NY                                   4.0
# addr_state:OK_TN_MO_LA_MD_NC                    4.0
# addr_state:CA                                   5.0
# addr_state:UT_KY_AZ_NJ                          6.0
# addr_state:AR_MI_PA_OH_MN                      10.0
# addr_state:RI_MA_DE_SD_IN                       7.0
# addr_state:GA_WA_OR                            14.0
# addr_state:WI_MT                               17.0
# addr_state:TX                                  17.0
# addr_state:IL_CT                               20.0
# addr_state:KS_SC_CO_VT_AK_MS                   25.0
# addr_state:WV_NH_WY_DC_ME_ID                   40.0
# verification_status:Not Verified                7.0
# verification_status:Source Verified            -1.0
# purpose:credit_card                            24.0
# purpose:debt_consolidation                     16.0
# purpose:oth__med__vacation                     17.0
# purpose:major_purch__car__home_impr            21.0
# initial_list_status:w                           4.0
# term:36                                         6.0
# emp_length:1                                    8.0
# emp_length:2-4                                 10.0
# emp_length:5-6                                  7.0
# emp_length:7-9                                  5.0
# emp_length:10                                  10.0
# mths_since_issue_d:<38                         85.0
# mths_since_issue_d:38-39                       69.0
# mths_since_issue_d:40-41                       61.0
# mths_since_issue_d:42-48                       46.0
# mths_since_issue_d:49-52                       33.0
# mths_since_issue_d:53-64                       14.0
# mths_since_issue_d:65-84                       -5.0
# int_rate:<9.548                                68.0
# int_rate:9.548-12.025                          43.0
# int_rate:12.025-15.74                          24.0
# int_rate:15.74-20.281                           9.0
# mths_since_earliest_cr_line:141-164             4.0
# mths_since_earliest_cr_line:165-247             3.0
# mths_since_earliest_cr_line:248-270             6.0
# mths_since_earliest_cr_line:271-352             9.0
# mths_since_earliest_cr_line:>352               10.0
# inq_last_6mths:0                               51.0
# inq_last_6mths:1-2                             40.0
# inq_last_6mths:3-6                             23.0
# acc_now_delinq:>=1                             16.0
# annual_inc:20K-30K                             -6.0
# annual_inc:30K-40K                             -1.0
# annual_inc:40K-50K                              6.0
# annual_inc:50K-60K                             11.0
# annual_inc:60K-70K                             17.0
# annual_inc:70K-80K                             23.0
# annual_inc:80K-90K                             29.0
# annual_inc:90K-100K                            30.0
# annual_inc:100K-120K                           36.0
# annual_inc:120K-140K                           43.0
# annual_inc:>140K                               39.0
# dti:<=1.4                                      19.0
# dti:1.4-3.5                                    28.0
# dti:3.5-7.7                                    29.0
# dti:7.7-10.5                                   24.0
# dti:10.5-16.1                                  18.0
# dti:16.1-20.3                                  10.0
# dti:20.3-21.7                                   9.0
# dti:21.7-22.4                                   7.0
# dti:22.4-35                                     3.0
# mths_since_last_delinq:Missing                 10.0
# mths_since_last_delinq:4-30                    12.0
# mths_since_last_delinq:31-56                   16.0
# mths_since_last_delinq:>=57                    12.0
# mths_since_last_record:Missing                 17.0
# mths_since_last_record:3-20                    26.0
# mths_since_last_record:21-31                   18.0
# mths_since_last_record:32-80                   31.0
# mths_since_last_record:81-86                    3.0
# mths_since_last_record:>=86                     9.0
# grade:G                                         0.0
# home_ownership:RENT_OTHER_NONE_ANY              0.0
# addr_state:ND_NE_IA_NV_FL_HI_AL                 0.0
# verification_status:Verified                    0.0
# purpose:educ__sm_b__wedd__ren_en__mov__house    0.0
# initial_list_status:f                           0.0
# term:60                                         0.0
# emp_length:0                                    0.0
# mths_since_issue_d:>84                          0.0
# int_rate:>20.281                                0.0
# mths_since_earliest_cr_line:<140                0.0
# inq_last_6mths:>6                               0.0
# acc_now_delinq:0                                0.0
# annual_inc:<20K                                 0.0
# dti:>35                                         0.0
# mths_since_last_delinq:0-3                      0.0
# mths_since_last_record:0-2                      0.0

# %% [markdown]
# # From Credit Score to PD

# %%
# y_scores is the score of every person in the test dataset
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
y_hat_proba_from_score.head()
# Out:
#                0
# 362514  0.924011
# 288564  0.844256
# 213591  0.887168
# 263083  0.940173
# 165001  0.968759

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.92430821, 0.84650386, 0.88566594, 0.94073658, 0.96878159])

# %% [markdown]
# # Cutoffs

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'],
                                 df_actual_predicted_probs['y_hat_test_proba'])

plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr
# 0    1.992670  0.000000  0.000000
# 1    0.992670  0.000000  0.000012
# 2    0.990715  0.000000  0.000120
# 3    0.990678  0.000098  0.000120
# 4    0.989778  0.000098  0.000445

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr   Score
# 0    1.000000  0.000000  0.000000  2077.0
# 1    0.992670  0.000000  0.000012   795.0
# 2    0.990715  0.000000  0.000120   776.0
# 3    0.990678  0.000098  0.000120   776.0
# 4    0.989778  0.000098  0.000445   769.0

# %%
df_cutoffs['Score'][0] = max_score
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score
# 0    1.000000  0.000000  0.000000  850.0
# 1    0.992670  0.000000  0.000012  795.0
# 2    0.990715  0.000000  0.000120  776.0
# 3    0.990678  0.000098  0.000120  776.0
# 4    0.989778  0.000098  0.000445  769.0

# %%
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]
df_cutoffs['Rejection Rate'] = 1 - df_cutoffs['Approval Rate']
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 0    1.000000  0.000000  0.000000  850.0           0       93257
# 1    0.992670  0.000000  0.000012  795.0           1       93256
# 2    0.990715  0.000000  0.000120  776.0          10       93247
# 3    0.990678  0.000098  0.000120  776.0          11       93246
# 4    0.989778  0.000098  0.000445  769.0          38       93219
#
#    Approval Rate  Rejection Rate
# 0       0.000000        1.000000
# 1       0.000011        0.999989
# 2       0.000107        0.999893
# 3       0.000118        0.999882
# 4       0.000407        0.999593

# %%
df_cutoffs
# Out:
#        thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 0        1.000000  0.000000  0.000000  850.0           0       93257
# 1        0.992670  0.000000  0.000012  795.0           1       93256
# 2        0.990715  0.000000  0.000120  776.0          10       93247
# 3        0.990678  0.000098  0.000120  776.0          11       93246
# 4        0.989778  0.000098  0.000445  769.0          38       93219
# ...           ...       ...       ...    ...         ...         ...
# 17347    0.488999  0.999607  0.999964  409.0       93250           7
# 17348    0.484370  0.999607  0.999976  407.0       93251           6
# 17349    0.448182  0.999902  0.999976  396.0       93254           3
# 17350    0.393928  0.999902  1.000000  379.0       93256           1
# 17351    0.393244  1.000000  1.000000  378.0       93257           0
#
#        Approval Rate  Rejection Rate
# 0           0.000000        1.000000
# 1           0.000011        0.999989
# 2           0.000107        0.999893
# 3           0.000118        0.999882
# 4           0.000407        0.999593
# ...              ...             ...
# 17347       0.999925        0.000075
# 17348       0.999936        0.000064
# 17349       0.999968        0.000032
# 17350       0.999989        0.000011
# 17351       1.000000        0.000000
#
# [17352 rows x 8 columns]

# %%
inputs_train_with_ref_cat.to_csv('inputs_train_with_ref_cat.csv')
df_scorecard.to_csv('df_scorecard.csv')
